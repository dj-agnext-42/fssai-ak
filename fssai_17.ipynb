# %%
import pandas as pd

# %%
df_new=pd.read_excel('fssai_new.xlsx',sheet_name='Sheet1')
df_new_Master=pd.read_excel('fssai_new.xlsx',sheet_name='Master')

# %%
df_new_Master
# Out:
#                         Category           Commodity           Test Type  \
# 0     Herbs, Spices & Condiments  Black Pepper Whole  Quality Parameters
# 1     Herbs, Spices & Condiments  Black Pepper Whole   Crop Contaminants
# 2     Herbs, Spices & Condiments  Black Pepper Whole  Metal Contaminants
# 3     Herbs, Spices & Condiments  Black Pepper Whole  Metal Contaminants
# 4     Herbs, Spices & Condiments  Black Pepper Whole  Metal Contaminants
# ...                          ...                 ...                 ...
# 3518  Herbs, Spices & Condiments      Turmeric Whole  Quality Parameters
# 3519  Herbs, Spices & Condiments      Turmeric Whole  Quality Parameters
# 3520  Herbs, Spices & Condiments      Turmeric Whole  Quality Parameters
# 3521  Herbs, Spices & Condiments      Turmeric Whole  Quality Parameters
# 3522  Herbs, Spices & Condiments      Turmeric Whole         Adulterants
#
#                                          Parameter  Units  \
# 0                           Added Colouring Matter  mg/kg
# 1                              Aflatoxin B1, µg/kg  µg/kg
# 2                             Arsenic as As, mg/kg  mg/kg
# 3                             Cadmium as Cd, mg/kg  mg/kg
# 4                              Copper as Cu, mg/kg  mg/kg
# ...                                            ...    ...
# 3518                                     Mustiness      %
# 3519                                         Mould      %
# 3520  Live insects, Dead Insects, Insect Fragments      %
# 3521                          Rodent Contamination      %
# 3522                                  Added Starch      %
#
#                                   Test Description Compliance  Test TAT  \
# 0     FSSAI Manual of Methods of Analysis of Foods      FSSAI       NaN
# 1     FSSAI Manual of Methods of Analysis of Foods      FSSAI       NaN
# 2     FSSAI Manual of Methods of Analysis of Foods      FSSAI       NaN
# 3     FSSAI Manual of Methods of Analysis of Foods      FSSAI       NaN
# 4     FSSAI Manual of Methods of Analysis of Foods      FSSAI       NaN
# ...                                            ...        ...       ...
# 3518  FSSAI Manual of Methods of Analysis of Foods      FSSAI       NaN
# 3519  FSSAI Manual of Methods of Analysis of Foods      FSSAI       NaN
# 3520  FSSAI Manual of Methods of Analysis of Foods      FSSAI       NaN
# 3521  FSSAI Manual of Methods of Analysis of Foods      FSSAI       NaN
# 3522  FSSAI Manual of Methods of Analysis of Foods      FSSAI       NaN
#
#       Method Key_Parameter  ...  Key Parameter (For Organic)  Unnamed: 18  \
# 0        NaN           Yes  ...                          Yes          NaN
# 1        NaN           Yes  ...                          Yes          NaN
# 2        NaN           Yes  ...                          Yes          NaN
# 3        NaN           Yes  ...                          Yes          NaN
# 4        NaN           Yes  ...                          Yes          NaN
# ...      ...           ...  ...                          ...          ...
# 3518     NaN           Yes  ...                          Yes          NaN
# 3519     NaN           Yes  ...                          Yes          NaN
# 3520     NaN           Yes  ...                          Yes          NaN
# 3521     NaN           Yes  ...                          Yes          NaN
# 3522     NaN           Yes  ...                          Yes          NaN
#
#                          Category, Commodity, Parameter  Unnamed: 20  \
# 0     Herbs, Spices & Condiments Black Pepper Whole ...          NaN
# 1     Herbs, Spices & Condiments Black Pepper Whole ...          NaN
# 2     Herbs, Spices & Condiments Black Pepper Whole ...          NaN
# 3     Herbs, Spices & Condiments Black Pepper Whole ...          NaN
# 4     Herbs, Spices & Condiments Black Pepper Whole ...          NaN
# ...                                                 ...          ...
# 3518  Herbs, Spices & Condiments Turmeric Whole Must...          NaN
# 3519    Herbs, Spices & Condiments Turmeric Whole Mould          NaN
# 3520  Herbs, Spices & Condiments Turmeric Whole Live...          NaN
# 3521  Herbs, Spices & Condiments Turmeric Whole Rode...          NaN
# 3522  Herbs, Spices & Condiments Turmeric Whole Adde...          NaN
#
#       Unnamed: 21  Unnamed: 22             Unique Category  \
# 0             NaN          NaN  Herbs, Spices & Condiments
# 1             NaN          NaN                         NaN
# 2             NaN          NaN                         NaN
# 3             NaN          NaN                         NaN
# 4             NaN          NaN                         NaN
# ...           ...          ...                         ...
# 3518          NaN          NaN                         NaN
# 3519          NaN          NaN                         NaN
# 3520          NaN          NaN                         NaN
# 3521          NaN          NaN                         NaN
# 3522          NaN          NaN                         NaN
#
#                  Unique Commodity  Unnamed: 25      Unnamed: 26
# 0              Black Pepper Whole          NaN  Package Created
# 1      Organic Black Pepper Whole          NaN  Package Created
# 2             Black Pepper Powder          NaN  Package Created
# 3     Organic Black Pepper Powder       Tested  Package Created
# 4                    Chilli whole          NaN  Package Created
# ...                           ...          ...              ...
# 3518                          NaN          NaN              NaN
# 3519                          NaN          NaN              NaN
# 3520                          NaN          NaN              NaN
# 3521                          NaN          NaN              NaN
# 3522                          NaN          NaN              NaN
#
# [3523 rows x 27 columns]

# %%
filtered_names = df_new_Master.loc[df_new_Master['Key_Parameter'] == 'No', 'Parameter'].tolist()

# %%
Banned_names = df_new_Master.loc[
    (df_new_Master['Key_Parameter'] == 'No') & 
    (df_new_Master['Test Type'] == 'Banned Pesticide Residue'), 
    'Parameter'
].drop_duplicates().tolist()
Not_Banned_names = df_new_Master.loc[
    (df_new_Master['Key_Parameter'] == 'No') & 
    (df_new_Master['Test Type'] == 'Pesticide Residue'), 
    'Parameter'
].drop_duplicates().tolist()

# %%
# columnsTokeep = df_new_Master.loc[
#     (df_new_Master['Key_Parameter'] == 'No') & 
#     (df_new_Master['Commodity'] == {SpecificCommodity}), 
#     'Parameter'
# ].drop_duplicates().tolist()

# %%
Banned_names
# Out:
# ['Methomyl, mg/kg',
#  'Carbofuran (sum of carbofuran and 3-hydroxy carbofuran expressed as carbofuran)',
#  'Methyl Parathion (combined residues of methyl parathion and its oxygen analogue to be determined and expressed as methyl parathion)',
#  'Aldicarb',
#  'Aldrin',
#  'Dieldrin',
#  'Chlordane',
#  'Heptalchlor',
#  'Lindane Gamma-HCH) Gamma (γ) Isomer (Known as Lindane)',
#  'Endosulfan',
#  'Phosphamidon',
#  'Captafol',
#  'Ferbam',
#  'Formothion',
#  'Simazine',
#  'Diazinon',
#  'D.D.T',
#  'Fenitrothion',
#  'Fenthion',
#  'Ethyl Parathion']

# %%
filtered_names
# Out:
# ['Acetamiprid, mg/kg',
#  'Alpha naphthyl Acetic Acid, mg/kg',
#  'Azoxystrobin, mg/kg',
#  'Buprofezin, mg/kg',
#  'Carbaryl, mg/kg',
#  'Carbosulfan, mg/kg',
#  'Chlorantraniliprole, mg/kg',
#  'Chlorfenapyr, mg/kg',
#  'Cuprous Oxide (Copper determined as elemental copper) mg/kg',
#  'Cyantranilipole, mg/kg',
#  'Deltamethrin/Decamethrin, mg/kg',
#  'Diafenthiuron, mg/kg',
#  'Dicofol (Sum of p,p and o,p isomers), mg/kg',
#  'Difenoconazole, mg/kg',
#  'Dimethoate, mg/kg',
#  'Fenazaquin, mg/kg',
#  'Fenpropathrin, mg/kg',
#  'Fenpyroximate, mg/kg',
#  'Fipronil, mg/kg',
#  'Flubendiamide, mg/kg',
#  'Flusilazole, mg/kg',
#  'Hexaconazole, mg/kg',
#  'Hexythiazox, mg/kg',
#  'Imidacloprid, mg/kg',
#  'Indoxacarb, mg/kg',
#  'Kresoxim methyl, mg/kg',
#  'Lambda cyhalothrin, mg/kg',
#  'Lufenuron, mg/kg',
#  'Methomyl, mg/kg',
#  'Milbemectin, mg/kg',
#  'Monocrotophos, mg/kg',
#  'Myclobutanil, mg/kg',
#  'Novaluron, mg/kg',
#  'Oxydemeton methyl, mg/kg',
#  'Pendimethalin, mg/kg',
#  'Picoxystrobin, mg/kg',
#  'Propargite, mg/kg',
#  'Propineb, mg/kg',
#  'Pyraclostrobin, mg/kg',
#  'Pyridalyl, mg/kg',
#  'Pyriproxyfen, mg/kg',
#  'Quinalphos, mg/kg',
#  'Spinosad, mg/kg',
#  'Spiromesifen, mg/kg',
#  'Tebuconazole, mg/kg',
#  'Thiacloprid, mg/kg',
#  'Thiodicarb, mg/kg',
#  'Thiamethoxam, mg/kg',
#  'Triadimefon, mg/kg',
#  'Trifloxystrobin, mg/kg',
#  'Triazophos, mg/kg',
#  'Tricyclazole, mg/kg',
#  'Spinetoram and its metabolites\n(Spinosyn-J and Spinosyn-L), mg/kg',
#  'Spirotetramat, mg/kg',
#  'Abamectin, mg/kg',
#  'Dithiocarbamates (the residue tolerance limit are determined and expressed as mg/CS2/kg and refer separately to the residues arising from any or each group of dithiocarbamates)',
#  'Metiram as CS2, mg/kg',
#  '(b) Ethylene bis- dithiocarbamates resulting from the use of mancozeb, maneb or zineb (including zineb derived from nabam plus zinc\nsulphate)',
#  '(e) Zineb as CS2',
#  '2,4-Dichlorophenoxy Acetic Acid',
#  'Acephate (expressed as mixture of Methamidophos and acephate).',
#  'Alachlor',
#  'Alpha cypermethrin',
#  'Ametroctradin',
#  'Anilophos',
#  'Atrazine',
#  'Azimsulfuron',
#  'Benfuracarb',
#  'Sum of benomyl and carbendazim expressed as carbendazim',
#  'Bensulfuron Methyl',
#  'Beta Cyfluthrin',
#  'Bifenthrin',
#  'Bispyribac Sodium',
#  'Bitertanol',
#  'Butachlor',
#  'Captan',
#  'Carbendazim',
#  'Carbofuran (sum of carbofuran and 3-hydroxy carbofuran expressed as carbofuran)',
#  'Carfentrazone Ethyl',
#  'Carpropamid',
#  'Cartap Hydrochloride',
#  'Chlorfluazuron',
#  'Chlorimuron ethyl',
#  'Chlormequat Chloride (CCC)',
#  'Chlorothalonil',
#  'Chlorpropham',
#  'Chlorpyriphos',
#  'Chlothianidin (Chlothianidin and its metabolites Thiazolymethylguanidine (TMG), Thiazolymethylurea (TZMU), Methylnitroguanidine (MNG) TMG)',
#  'Chromafenozide',
#  'Cinmethylene',
#  'Clodinafop-propargyl',
#  'Clomazone',
#  'Copper Hydroxide (Copper determined as elemental copper)',
#  'Copper Sulphate (Copper determined as elemental copper',
#  'Cyazofamid',
#  'Cyhalofop-butyl',
#  'Cymoxanil',
#  'Cypermethrin (sum of isomers) (Fat soluble residue)',
#  'Dichlorvos (DDVP) (content of di- chloroacetaldehyde (D.C.A.) be reported where possible)',
#  'Diclofop (sum diclofop-methyl and diclofop\nacid expressed as diclofop-methyl)”',
#  'Diclosulam',
#  'Diflubenzuron',
#  'Dimethomorph',
#  'Dinocap',
#  'Dinotefuran',
#  'Dithianon',
#  'Diuron',
#  'Dodine',
#  'Edifenphos',
#  'Emamectin Benzoate',
#  'Epoxyconazole, mg/kg',
#  'Ethephon',
#  'Ethion(Residues to be determined as ethion and its oxygen analogue and expressed as ethion)',
#  'Ethofenprox (Etofenprox)',
#  'Ethoxysulfuron',
#  'Etoxazole',
#  'Famoxadone',
#  'Fenamidone',
#  'Fenarimol',
#  'Fenobucarb (BPMC)',
#  'Fenoxaprop-p-ethyl',
#  'Fenvalerate (Fat soluble residue)',
#  'Flonicamid',
#  'Fluazifop-p-butyl',
#  'Fluchloralin',
#  'Flufenacet',
#  'Fluvalinate',
#  'Forchlorfenuron',
#  'Fosetyl-Al, mg/kg',
#  'Glufosinate Ammonium',
#  'Glyphosate',
#  'Halosulfuron methyl',
#  'Hexazinone',
#  'Hydrogen Cyanamide',
#  'Iodosulfuron Methyl Sodium',
#  'Imazethapyr',
#  'Iprobenfos (Kitazin)',
#  'Iprodione',
#  'Isoprothiolane',
#  'Isoproturon',
#  'Kasugamycin',
#  'Linuron',
#  'Malathion (Malathion to be determined and expressed as combined residues of malathion and malaoxon)',
#  'Mandipropamid',
#  'Mepiquat Chloride',
#  'Mesosulfuron Methyl',
#  'Metaflumizone',
#  'Metalaxyl',
#  'Methabenzthiazuron',
#  'Methyl Chlorophenoxy Acetic Acid (MCPA)',
#  'Methyl Parathion (combined residues of methyl parathion and its oxygen analogue to be determined and expressed as methyl parathion)',
#  'Metolachlor',
#  'Metribuzin',
#  'Metsulfuron Methyl',
#  'Orthosulfamuron',
#  'Oxadiargyl, mg/kg',
#  'Oxadiazon',
#  'Oxyfluorfen',
#  'Paclobutrazol',
#  'Paraquat dichloride (Determined as Paraquatcations)',
#  'Penconazole',
#  'Pencycuron',
#  'Penoxuslum',
#  'Permethrin',
#  'Phenthoate',
#  'Phorate (sum of Phorate, its oxygen analogue and their sulphoxides and sulphones, expressed as phorate)',
#  'Phosalone',
#  'Pinoxaden',
#  'Pretilachlor',
#  'Pirimiphos-methyl',
#  'Profenofos',
#  'Prohexadione calcium',
#  'Propaquizafop',
#  'Propiconazole',
#  'Pyrazosulfuron ethyl',
#  'Pyrithiolac Sodium',
#  'Pymetrozine',
#  'Quizalofop ethyl',
#  'Quizalofop-P-tefuryl',
#  'Sodium Aceflourofen',
#  'Sulfosulfuron',
#  'Thifluzamide',
#  'Thiometon(Residues determined as thiometon its sulfoxide and sulphone expressed as thiometon)',
#  'Thiophanate-Methyl',
#  'Tolfenpyrad',
#  'Trichlorfon',
#  'Triacontanol',
#  'Triallate',
#  'Triasulfuron',
#  'Tridemorph',
#  'Trifluralin',
#  'Validamycin',
#  'Fluopicolide',
#  'Tembotrione',
#  'Propanil',
#  'Fluopyram and its metabolites',
#  'Topramezone',
#  'Thiocyclam Hydrogen Oxalate',
#  '2,4-D Amine Salt',
#  'Ametyrn',
#  'Fomesafen',
#  'Imazamox',
#  'Sodium Para Nitro Phenolate',
#  'Bentazone',
#  'Cyflumetofen',
#  'Boscalid',
#  'Flucetosulfuron',
#  'Haloxyfop-R Methyl',
#  'Sulfentrazone and its metabolite Desmethylsulfentrazone and 3- Hydroxymethylsulfentrazone',
#  'Metrafenone',
#  'Fluxapyroxad',
#  'Tetraconazole',
#  'Flupyradifurone and its metabolites Difluroacetic Acid and Difluroethylamino- furanone',
#  'Sulfoxaflor',
#  'Aldicarb',
#  'Aldrin',
#  'Dieldrin',
#  'Chlordane',
#  'Heptalchlor',
#  'Lindane Gamma-HCH) Gamma (γ) Isomer (Known as Lindane)',
#  'Endosulfan',
#  'Phosphamidon',
#  'Captafol',
#  'Ferbam',
#  'Formothion',
#  'Simazine',
#  'Diazinon',
#  'D.D.T',
#  'Fenitrothion',
#  'Fenthion',
#  'Ethyl Parathion',
#  'Acetamiprid, mg/kg',
#  'Alpha naphthyl Acetic Acid, mg/kg',
#  'Azoxystrobin, mg/kg',
#  'Buprofezin, mg/kg',
#  'Carbaryl, mg/kg',
#  'Carbosulfan, mg/kg',
#  'Chlorantraniliprole, mg/kg',
#  'Chlorfenapyr, mg/kg',
#  'Cuprous Oxide (Copper determined as elemental copper) mg/kg',
#  'Cyantranilipole, mg/kg',
#  'Deltamethrin/Decamethrin, mg/kg',
#  'Diafenthiuron, mg/kg',
#  'Dicofol (Sum of p,p and o,p isomers), mg/kg',
#  'Difenoconazole, mg/kg',
#  'Dimethoate, mg/kg',
#  'Fenazaquin, mg/kg',
#  'Fenpropathrin, mg/kg',
#  'Fenpyroximate, mg/kg',
#  'Fipronil, mg/kg',
#  'Flubendiamide, mg/kg',
#  'Flusilazole, mg/kg',
#  'Hexaconazole, mg/kg',
#  'Hexythiazox, mg/kg',
#  'Imidacloprid, mg/kg',
#  'Indoxacarb, mg/kg',
#  'Kresoxim methyl, mg/kg',
#  'Lambda cyhalothrin, mg/kg',
#  'Lufenuron, mg/kg',
#  'Methomyl, mg/kg',
#  'Milbemectin, mg/kg',
#  'Monocrotophos, mg/kg',
#  'Myclobutanil, mg/kg',
#  'Novaluron, mg/kg',
#  'Oxydemeton methyl, mg/kg',
#  'Pendimethalin, mg/kg',
#  'Picoxystrobin, mg/kg',
#  'Propargite, mg/kg',
#  'Propineb, mg/kg',
#  'Pyraclostrobin, mg/kg',
#  'Pyridalyl, mg/kg',
#  'Pyriproxyfen, mg/kg',
#  'Quinalphos, mg/kg',
#  'Spinosad, mg/kg',
#  'Spiromesifen, mg/kg',
#  'Tebuconazole, mg/kg',
#  'Thiacloprid, mg/kg',
#  'Thiodicarb, mg/kg',
#  'Thiamethoxam, mg/kg',
#  'Triadimefon, mg/kg',
#  'Trifloxystrobin, mg/kg',
#  'Triazophos, mg/kg',
#  'Tricyclazole, mg/kg',
#  'Spinetoram and its metabolites\n(Spinosyn-J and Spinosyn-L), mg/kg',
#  'Spirotetramat, mg/kg',
#  'Abamectin, mg/kg',
#  'Dithiocarbamates (the residue tolerance limit are determined and expressed as mg/CS2/kg and refer separately to the residues arising from any or each group of dithiocarbamates)',
#  'Metiram as CS2, mg/kg',
#  '(b) Ethylene bis- dithiocarbamates resulting from the use of mancozeb, maneb or zineb (including zineb derived from nabam plus zinc\nsulphate)',
#  '(e) Zineb as CS2',
#  '2,4-Dichlorophenoxy Acetic Acid',
#  'Acephate (expressed as mixture of Methamidophos and acephate).',
#  'Alachlor',
#  'Alpha cypermethrin',
#  'Ametroctradin',
#  'Anilophos',
#  'Atrazine',
#  'Azimsulfuron',
#  'Benfuracarb',
#  'Sum of benomyl and carbendazim expressed as carbendazim',
#  'Bensulfuron Methyl',
#  'Beta Cyfluthrin',
#  'Bifenthrin',
#  'Bispyribac Sodium',
#  'Bitertanol',
#  'Butachlor',
#  'Captan',
#  'Carbendazim',
#  'Carbofuran (sum of carbofuran and 3-hydroxy carbofuran expressed as carbofuran)',
#  'Carfentrazone Ethyl',
#  'Carpropamid',
#  'Cartap Hydrochloride',
#  'Chlorfluazuron',
#  'Chlorimuron ethyl',
#  'Chlormequat Chloride (CCC)',
#  'Chlorothalonil',
#  'Chlorpropham',
#  'Chlorpyriphos',
#  'Chlothianidin (Chlothianidin and its metabolites Thiazolymethylguanidine (TMG), Thiazolymethylurea (TZMU), Methylnitroguanidine (MNG) TMG)',
#  'Chromafenozide',
#  'Cinmethylene',
#  'Clodinafop-propargyl',
#  'Clomazone',
#  'Copper Hydroxide (Copper determined as elemental copper)',
#  'Copper Sulphate (Copper determined as elemental copper',
#  'Cyazofamid',
#  'Cyhalofop-butyl',
#  'Cymoxanil',
#  'Cypermethrin (sum of isomers) (Fat soluble residue)',
#  'Dichlorvos (DDVP) (content of di- chloroacetaldehyde (D.C.A.) be reported where possible)',
#  'Diclofop (sum diclofop-methyl and diclofop\nacid expressed as diclofop-methyl)”',
#  'Diclosulam',
#  'Diflubenzuron',
#  'Dimethomorph',
#  'Dinocap',
#  'Dinotefuran',
#  'Dithianon',
#  'Diuron',
#  'Dodine',
#  'Edifenphos',
#  'Emamectin Benzoate',
#  'Epoxyconazole, mg/kg',
#  'Ethephon',
#  'Ethion(Residues to be determined as ethion and its oxygen analogue and expressed as ethion)',
#  'Ethofenprox (Etofenprox)',
#  'Ethoxysulfuron',
#  'Etoxazole',
#  'Famoxadone',
#  'Fenamidone',
#  'Fenarimol',
#  'Fenobucarb (BPMC)',
#  'Fenoxaprop-p-ethyl',
#  'Fenvalerate (Fat soluble residue)',
#  'Flonicamid',
#  'Fluazifop-p-butyl',
#  'Fluchloralin',
#  'Flufenacet',
#  'Fluvalinate',
#  'Forchlorfenuron',
#  'Fosetyl-Al, mg/kg',
#  'Glufosinate Ammonium',
#  'Glyphosate',
#  'Halosulfuron methyl',
#  'Hexazinone',
#  'Hydrogen Cyanamide',
#  'Iodosulfuron Methyl Sodium',
#  'Imazethapyr',
#  'Iprobenfos (Kitazin)',
#  'Iprodione',
#  'Isoprothiolane',
#  'Isoproturon',
#  'Kasugamycin',
#  'Linuron',
#  'Malathion (Malathion to be determined and expressed as combined residues of malathion and malaoxon)',
#  'Mandipropamid',
#  'Mepiquat Chloride',
#  'Mesosulfuron Methyl',
#  'Metaflumizone',
#  'Metalaxyl',
#  'Methabenzthiazuron',
#  'Methyl Chlorophenoxy Acetic Acid (MCPA)',
#  'Methyl Parathion (combined residues of methyl parathion and its oxygen analogue to be determined and expressed as methyl parathion)',
#  'Metolachlor',
#  'Metribuzin',
#  'Metsulfuron Methyl',
#  'Orthosulfamuron',
#  'Oxadiargyl, mg/kg',
#  'Oxadiazon',
#  'Oxyfluorfen',
#  'Paclobutrazol',
#  'Paraquat dichloride (Determined as Paraquatcations)',
#  'Penconazole',
#  'Pencycuron',
#  'Penoxuslum',
#  'Permethrin',
#  'Phenthoate',
#  'Phorate (sum of Phorate, its oxygen analogue and their sulphoxides and sulphones, expressed as phorate)',
#  'Phosalone',
#  'Pinoxaden',
#  'Pretilachlor',
#  'Pirimiphos-methyl',
#  'Profenofos',
#  'Prohexadione calcium',
#  'Propaquizafop',
#  'Propiconazole',
#  'Pyrazosulfuron ethyl',
#  'Pyrithiolac Sodium',
#  'Pymetrozine',
#  'Quizalofop ethyl',
#  'Quizalofop-P-tefuryl',
#  'Sodium Aceflourofen',
#  'Sulfosulfuron',
#  'Thifluzamide',
#  'Thiometon(Residues determined as thiometon its sulfoxide and sulphone expressed as thiometon)',
#  'Thiophanate-Methyl',
#  'Tolfenpyrad',
#  'Trichlorfon',
#  'Triacontanol',
#  'Triallate',
#  'Triasulfuron',
#  'Tridemorph',
#  'Trifluralin',
#  'Validamycin',
#  'Fluopicolide',
#  'Tembotrione',
#  'Propanil',
#  'Fluopyram and its metabolites',
#  'Topramezone',
#  'Thiocyclam Hydrogen Oxalate',
#  '2,4-D Amine Salt',
#  'Ametyrn',
#  'Fomesafen',
#  'Imazamox',
#  'Sodium Para Nitro Phenolate',
#  'Bentazone',
#  'Cyflumetofen',
#  'Boscalid',
#  'Flucetosulfuron',
#  'Haloxyfop-R Methyl',
#  'Sulfentrazone and its metabolite Desmethylsulfentrazone and 3- Hydroxymethylsulfentrazone',
#  'Metrafenone',
#  'Fluxapyroxad',
#  'Tetraconazole',
#  'Flupyradifurone and its metabolites Difluroacetic Acid and Difluroethylamino- furanone',
#  'Sulfoxaflor',
#  'Aldicarb',
#  'Aldrin',
#  'Dieldrin',
#  'Chlordane',
#  'Heptalchlor',
#  'Lindane Gamma-HCH) Gamma (γ) Isomer (Known as Lindane)',
#  'Endosulfan',
#  'Phosphamidon',
#  'Captafol',
#  'Ferbam',
#  'Formothion',
#  'Simazine',
#  'Diazinon',
#  'D.D.T',
#  'Fenitrothion',
#  'Fenthion',
#  'Ethyl Parathion',
#  'Acetamiprid, mg/kg',
#  'Alpha naphthyl Acetic Acid, mg/kg',
#  'Azoxystrobin, mg/kg',
#  'Buprofezin, mg/kg',
#  'Carbaryl, mg/kg',
#  'Carbosulfan, mg/kg',
#  'Chlorantraniliprole, mg/kg',
#  'Chlorfenapyr, mg/kg',
#  'Cuprous Oxide (Copper determined as elemental copper) mg/kg',
#  'Cyantranilipole, mg/kg',
#  'Deltamethrin/Decamethrin, mg/kg',
#  'Dicofol (Sum of p,p and o,p isomers), mg/kg',
#  'Difenoconazole, mg/kg',
#  'Dimethoate, mg/kg',
#  'Fenazaquin, mg/kg',
#  'Fenpropathrin, mg/kg',
#  'Fenpyroximate, mg/kg',
#  'Fipronil, mg/kg',
#  'Flubendiamide, mg/kg',
#  'Flusilazole, mg/kg',
#  'Hexaconazole, mg/kg',
#  'Hexythiazox, mg/kg',
#  'Imidacloprid, mg/kg',
#  'Indoxacarb, mg/kg',
#  'Kresoxim methyl, mg/kg',
#  'Lambda cyhalothrin, mg/kg',
#  'Lufenuron, mg/kg',
#  'Metalaxyl-M, mg/kg',
#  'Methomyl, mg/kg',
#  'Milbemectin, mg/kg',
#  'Myclobutanil, mg/kg',
#  'Novaluron, mg/kg',
#  'Oxydemeton methyl, mg/kg',
#  'Pendimethalin, mg/kg',
#  'Picoxystrobin, mg/kg',
#  'Propargite, mg/kg',
#  'Propineb, mg/kg',
#  'Pyraclostrobin, mg/kg',
#  'Pyridalyl, mg/kg',
#  'Pyriproxyfen, mg/kg',
#  'Spinosad, mg/kg',
#  'Spiromesifen, mg/kg',
#  'Tebuconazole, mg/kg',
#  'Thiacloprid, mg/kg',
#  'Thiodicarb, mg/kg',
#  'Thiamethoxam, mg/kg',
#  'Triadimefon, mg/kg',
#  'Trifloxystrobin, mg/kg',
#  'Triazophos, mg/kg',
#  'Tricyclazole, mg/kg',
#  'Spinetoram and its metabolites\n(Spinosyn-J and Spinosyn-L), mg/kg',
#  'Spirotetramat, mg/kg',
#  'Abamectin, mg/kg',
#  'Dithiocarbamates (the residue tolerance limit are determined and expressed as mg/CS2/kg and refer separately to the residues arising from any or each group of dithiocarbamates)',
#  'Mancozeb, mg/kg',
#  'Metiram as CS2, mg/kg',
#  '(b) Ethylene bis- dithiocarbamates resulting from the use of mancozeb, maneb or zineb (including zineb derived from nabam plus zinc\nsulphate)',
#  '(e) Zineb as CS2',
#  '2,4-Dichlorophenoxy Acetic Acid',
#  'Acephate (expressed as mixture of Methamidophos and acephate).',
#  'Alachlor',
#  'Alpha cypermethrin',
#  'Ametroctradin',
#  'Anilophos',
#  'Atrazine',
#  'Azimsulfuron',
#  'Benfuracarb',
#  'Sum of benomyl and carbendazim expressed as carbendazim',
#  'Bensulfuron Methyl',
#  'Beta Cyfluthrin',
#  'Bifenthrin',
#  'Bispyribac Sodium',
#  'Bitertanol',
#  'Butachlor',
#  'Captan',
#  'Carbendazim',
#  'Carbofuran (sum of carbofuran and 3-hydroxy carbofuran expressed as carbofuran)',
#  'Carfentrazone Ethyl',
#  'Carpropamid',
#  'Cartap Hydrochloride',
#  'Chlorfluazuron',
#  'Chlorimuron ethyl',
#  'Chlormequat Chloride (CCC)',
#  'Chlorothalonil',
#  'Chlorpropham',
#  'Chlorpyriphos',
#  'Chlothianidin (Chlothianidin and its metabolites Thiazolymethylguanidine (TMG), Thiazolymethylurea (TZMU), Methylnitroguanidine (MNG) TMG)',
#  'Chromafenozide',
#  'Cinmethylene',
#  'Clodinafop-propargyl',
#  'Clomazone',
#  'Copper Hydroxide (Copper determined as elemental copper)',
#  'Cyazofamid',
#  'Cyhalofop-butyl',
#  'Cymoxanil',
#  'Cypermethrin (sum of isomers) (Fat soluble residue)',
#  'Dichlorvos (DDVP) (content of di- chloroacetaldehyde (D.C.A.) be reported where possible)',
#  'Diclofop (sum diclofop-methyl and diclofop\nacid expressed as diclofop-methyl)”',
#  'Diclosulam',
#  'Diflubenzuron',
#  'Dimethomorph',
#  'Dinocap',
#  'Dinotefuran',
#  'Dithianon',
#  'Diuron',
#  'Dodine',
#  'Edifenphos',
#  'Emamectin Benzoate',
#  'Epoxyconazole, mg/kg',
#  'Ethephon',
#  'Ethion(Residues to be determined as ethion and its oxygen analogue and expressed as ethion)',
#  'Ethofenprox (Etofenprox)',
#  'Ethoxysulfuron',
#  'Etoxazole',
#  'Famoxadone',
#  'Fenamidone',
#  'Fenarimol',
#  'Fenobucarb (BPMC)',
#  'Fenoxaprop-p-ethyl',
#  'Fenvalerate (Fat soluble residue)',
#  'Flonicamid',
#  'Fluazifop-p-butyl',
#  'Fluchloralin',
#  'Flufenacet',
#  'Fluvalinate',
#  'Forchlorfenuron',
#  'Fosetyl-Al, mg/kg',
#  'Glufosinate Ammonium',
#  'Glyphosate',
#  'Halosulfuron methyl',
#  'Hexazinone',
#  'Hydrogen Cyanamide',
#  'Iodosulfuron Methyl Sodium',
#  'Imazethapyr',
#  'Iprobenfos (Kitazin)',
#  'Iprodione',
#  'Isoprothiolane',
#  'Isoproturon',
#  'Kasugamycin',
#  'Linuron',
#  'Malathion (Malathion to be determined and expressed as combined residues of malathion and malaoxon)',
#  'Mandipropamid',
#  'Mepiquat Chloride',
#  'Mesosulfuron Methyl',
#  'Metaflumizone',
#  'Metalaxyl',
#  'Methabenzthiazuron',
#  'Methyl Chlorophenoxy Acetic Acid (MCPA)',
#  'Methyl Parathion (combined residues of methyl parathion and its oxygen analogue to be determined and expressed as methyl parathion)',
#  'Metolachlor',
#  'Metribuzin',
#  'Metsulfuron Methyl',
#  'Orthosulfamuron',
#  'Oxadiargyl, mg/kg',
#  'Oxadiazon',
#  'Oxyfluorfen',
#  'Paclobutrazol',
#  'Paraquat dichloride (Determined as Paraquatcations)',
#  'Penconazole',
#  'Pencycuron',
#  'Penoxuslum',
#  'Permethrin',
#  'Phenthoate',
#  'Phorate (sum of Phorate, its oxygen analogue and their sulphoxides and sulphones, expressed as phorate)',
#  'Phosalone',
#  'Pinoxaden',
#  'Pretilachlor',
#  'Pirimiphos-methyl',
#  'Profenofos',
#  'Prohexadione calcium',
#  'Propaquizafop',
#  'Propiconazole',
#  'Pyrazosulfuron ethyl',
#  'Pyrithiolac Sodium',
#  'Pymetrozine',
#  'Quizalofop ethyl',
#  'Quizalofop-P-tefuryl',
#  'Sodium Aceflourofen',
#  'Sulfosulfuron',
#  'Thifluzamide',
#  'Thiometon(Residues determined as thiometon its sulfoxide and sulphone expressed as thiometon)',
#  'Thiophanate-Methyl',
#  'Tolfenpyrad',
#  'Trichlorfon',
#  'Triacontanol',
#  'Triallate',
#  'Triasulfuron',
#  'Tridemorph',
#  'Trifluralin',
#  'Validamycin',
#  'Fluopicolide',
#  'Tembotrione',
#  'Propanil',
#  'Fluopyram and its metabolites',
#  'Topramezone',
#  'Thiocyclam Hydrogen Oxalate',
#  '2,4-D Amine Salt',
#  'Ametyrn',
#  'Fomesafen',
#  'Imazamox',
#  'Sodium Para Nitro Phenolate',
#  'Bentazone',
#  'Cyflumetofen',
#  'Boscalid',
#  'Flucetosulfuron',
#  'Haloxyfop-R Methyl',
#  'Sulfentrazone and its metabolite Desmethylsulfentrazone and 3- Hydroxymethylsulfentrazone',
#  'Metrafenone',
#  'Fluxapyroxad',
#  'Tetraconazole',
#  'Flupyradifurone and its metabolites Difluroacetic Acid and Difluroethylamino- furanone',
#  'Sulfoxaflor',
#  'Aldicarb',
#  'Aldrin',
#  'Dieldrin',
#  'Chlordane',
#  'Heptalchlor',
#  'Lindane Gamma-HCH) Gamma (γ) Isomer (Known as Lindane)',
#  'Endosulfan',
#  'Phosphamidon',
#  'Captafol',
#  'Ferbam',
#  'Formothion',
#  'Simazine',
#  'Diazinon',
#  'D.D.T',
#  'Fenitrothion',
#  'Fenthion',
#  'Ethyl Parathion',
#  'Acetamiprid, mg/kg',
#  'Alpha naphthyl Acetic Acid, mg/kg',
#  'Azoxystrobin, mg/kg',
#  'Buprofezin, mg/kg',
#  'Carbaryl, mg/kg',
#  'Carbosulfan, mg/kg',
#  'Chlorantraniliprole, mg/kg',
#  'Chlorfenapyr, mg/kg',
#  'Cuprous Oxide (Copper determined as elemental copper) mg/kg',
#  'Cyantranilipole, mg/kg',
#  'Deltamethrin/Decamethrin, mg/kg',
#  'Dicofol (Sum of p,p and o,p isomers), mg/kg',
#  'Difenoconazole, mg/kg',
#  'Dimethoate, mg/kg',
#  'Fenazaquin, mg/kg',
#  'Fenpropathrin, mg/kg',
#  'Fenpyroximate, mg/kg',
#  'Fipronil, mg/kg',
#  'Flubendiamide, mg/kg',
#  'Flusilazole, mg/kg',
#  'Hexaconazole, mg/kg',
#  'Hexythiazox, mg/kg',
#  'Imidacloprid, mg/kg',
#  'Indoxacarb, mg/kg',
#  'Kresoxim methyl, mg/kg',
#  'Lambda cyhalothrin, mg/kg',
#  'Lufenuron, mg/kg',
#  'Metalaxyl-M, mg/kg',
#  'Methomyl, mg/kg',
#  'Milbemectin, mg/kg',
#  'Myclobutanil, mg/kg',
#  'Novaluron, mg/kg',
#  'Oxydemeton methyl, mg/kg',
#  'Pendimethalin, mg/kg',
#  'Picoxystrobin, mg/kg',
#  'Propargite, mg/kg',
#  'Propineb, mg/kg',
#  'Pyraclostrobin, mg/kg',
#  'Pyridalyl, mg/kg',
#  'Pyriproxyfen, mg/kg',
#  'Spinosad, mg/kg',
#  'Spiromesifen, mg/kg',
#  'Tebuconazole, mg/kg',
#  'Thiacloprid, mg/kg',
#  'Thiodicarb, mg/kg',
#  'Thiamethoxam, mg/kg',
#  'Triadimefon, mg/kg',
#  'Trifloxystrobin, mg/kg',
#  'Triazophos, mg/kg',
#  'Tricyclazole, mg/kg',
#  'Spinetoram and its metabolites\n(Spinosyn-J and Spinosyn-L), mg/kg',
#  'Spirotetramat, mg/kg',
#  'Abamectin, mg/kg',
#  'Dithiocarbamates (the residue tolerance limit are determined and expressed as mg/CS2/kg and refer separately to the residues arising from any or each group of dithiocarbamates)',
#  'Mancozeb, mg/kg',
#  'Metiram as CS2, mg/kg',
#  '(b) Ethylene bis- dithiocarbamates resulting from the use of mancozeb, maneb or zineb (including zineb derived from nabam plus zinc\nsulphate)',
#  '(e) Zineb as CS2',
#  '2,4-Dichlorophenoxy Acetic Acid',
#  'Acephate (expressed as mixture of Methamidophos and acephate).',
#  'Alachlor',
#  'Alpha cypermethrin',
#  'Ametroctradin',
#  'Anilophos',
#  'Atrazine',
#  'Azimsulfuron',
#  'Benfuracarb',
#  'Sum of benomyl and carbendazim expressed as carbendazim',
#  'Bensulfuron Methyl',
#  'Beta Cyfluthrin',
#  'Bifenthrin',
#  'Bispyribac Sodium',
#  'Bitertanol',
#  'Butachlor',
#  'Captan',
#  'Carbendazim',
#  'Carbofuran (sum of carbofuran and 3-hydroxy carbofuran expressed as carbofuran)',
#  'Carfentrazone Ethyl',
#  'Carpropamid',
#  'Cartap Hydrochloride',
#  'Chlorfluazuron',
#  'Chlorimuron ethyl',
#  'Chlormequat Chloride (CCC)',
#  'Chlorothalonil',
#  'Chlorpropham',
#  'Chlorpyriphos',
#  'Chlothianidin (Chlothianidin and its metabolites Thiazolymethylguanidine (TMG), Thiazolymethylurea (TZMU), Methylnitroguanidine (MNG) TMG)',
#  'Chromafenozide',
#  'Cinmethylene',
#  'Clodinafop-propargyl',
#  'Clomazone',
#  'Copper Hydroxide (Copper determined as elemental copper)',
#  'Cyazofamid',
#  'Cyhalofop-butyl',
#  'Cymoxanil',
#  'Cypermethrin (sum of isomers) (Fat soluble residue)',
#  'Dichlorvos (DDVP) (content of di- chloroacetaldehyde (D.C.A.) be reported where possible)',
#  'Diclofop (sum diclofop-methyl and diclofop\nacid expressed as diclofop-methyl)”',
#  'Diclosulam',
#  'Diflubenzuron',
#  'Dimethomorph',
#  'Dinocap',
#  'Dinotefuran',
#  'Dithianon',
#  'Diuron',
#  'Dodine',
#  'Edifenphos',
#  'Emamectin Benzoate',
#  'Epoxyconazole, mg/kg',
#  'Ethephon',
#  'Ethion(Residues to be determined as ethion and its oxygen analogue and expressed as ethion)',
#  'Ethofenprox (Etofenprox)',
#  'Ethoxysulfuron',
#  'Etoxazole',
#  'Famoxadone',
#  'Fenamidone',
#  'Fenarimol',
#  'Fenobucarb (BPMC)',
#  'Fenoxaprop-p-ethyl',
#  'Fenvalerate (Fat soluble residue)',
#  'Flonicamid',
#  'Fluazifop-p-butyl',
#  'Fluchloralin',
#  'Flufenacet',
#  'Fluvalinate',
#  'Forchlorfenuron',
#  'Fosetyl-Al, mg/kg',
#  'Glufosinate Ammonium',
#  'Glyphosate',
#  'Halosulfuron methyl',
#  'Hexazinone',
#  'Hydrogen Cyanamide',
#  'Iodosulfuron Methyl Sodium',
#  'Imazethapyr',
#  'Iprobenfos (Kitazin)',
#  'Iprodione',
#  'Isoprothiolane',
#  'Isoproturon',
#  'Kasugamycin',
#  'Linuron',
#  'Malathion (Malathion to be determined and expressed as combined residues of malathion and malaoxon)',
#  'Mandipropamid',
#  'Mepiquat Chloride',
#  'Mesosulfuron Methyl',
#  'Metaflumizone',
#  'Metalaxyl',
#  'Methabenzthiazuron',
#  'Methyl Chlorophenoxy Acetic Acid (MCPA)',
#  'Methyl Parathion (combined residues of methyl parathion and its oxygen analogue to be determined and expressed as methyl parathion)',
#  'Metolachlor',
#  'Metribuzin',
#  'Metsulfuron Methyl',
#  'Orthosulfamuron',
#  'Oxadiargyl, mg/kg',
#  'Oxadiazon',
#  'Oxyfluorfen',
#  'Paclobutrazol',
#  'Paraquat dichloride (Determined as Paraquatcations)',
#  'Penconazole',
#  'Pencycuron',
#  'Penoxuslum',
#  'Permethrin',
#  'Phenthoate',
#  'Phorate (sum of Phorate, its oxygen analogue and their sulphoxides and sulphones, expressed as phorate)',
#  'Phosalone',
#  'Pinoxaden',
#  'Pretilachlor',
#  'Pirimiphos-methyl',
#  'Profenofos',
#  'Prohexadione calcium',
#  'Propaquizafop',
#  'Propiconazole',
#  'Pyrazosulfuron ethyl',
#  'Pyrithiolac Sodium',
#  'Pymetrozine',
#  'Quizalofop ethyl',
#  'Quizalofop-P-tefuryl',
#  'Sodium Aceflourofen',
#  'Sulfosulfuron',
#  'Thifluzamide',
#  'Thiometon(Residues determined as thiometon its sulfoxide and sulphone expressed as thiometon)',
#  'Thiophanate-Methyl',
#  'Tolfenpyrad',
#  'Trichlorfon',
#  'Triacontanol',
#  'Triallate',
#  'Triasulfuron',
#  'Tridemorph',
#  'Trifluralin',
#  'Validamycin',
#  'Fluopicolide',
#  'Tembotrione',
#  'Propanil',
#  'Fluopyram and its metabolites',
#  'Topramezone',
#  'Thiocyclam Hydrogen Oxalate',
#  '2,4-D Amine Salt',
#  'Ametyrn',
#  'Fomesafen',
#  'Imazamox',
#  'Sodium Para Nitro Phenolate',
#  'Bentazone',
#  'Cyflumetofen',
#  'Boscalid',
#  'Flucetosulfuron',
#  'Haloxyfop-R Methyl',
#  'Sulfentrazone and its metabolite Desmethylsulfentrazone and 3- Hydroxymethylsulfentrazone',
#  'Metrafenone',
#  'Fluxapyroxad',
#  'Tetraconazole',
#  'Flupyradifurone and its metabolites Difluroacetic Acid and Difluroethylamino- furanone',
#  'Sulfoxaflor',
#  'Aldicarb',
#  'Aldrin',
#  'Dieldrin',
#  'Chlordane',
#  'Heptalchlor',
#  'Lindane Gamma-HCH) Gamma (γ) Isomer (Known as Lindane)',
#  'Endosulfan',
#  'Phosphamidon',
#  'Captafol',
#  'Ferbam',
#  'Formothion',
#  'Simazine',
#  'Diazinon',
#  'D.D.T',
#  'Fenitrothion',
#  'Fenthion',
#  'Ethyl Parathion',
#  'Acetamiprid, mg/kg',
#  'Alpha naphthyl Acetic Acid, mg/kg',
#  'Azoxystrobin, mg/kg',
#  'Buprofezin, mg/kg',
#  'Carbaryl, mg/kg',
#  'Carbosulfan, mg/kg',
#  'Chlorantraniliprole, mg/kg',
#  'Chlorfenapyr, mg/kg',
#  'Cuprous Oxide (Copper determined as elemental copper) mg/kg',
#  'Cyantranilipole, mg/kg',
#  'Deltamethrin/Decamethrin, mg/kg',
#  'Diafenthiuron, mg/kg',
#  'Dicofol (Sum of p,p and o,p isomers), mg/kg',
#  'Difenoconazole, mg/kg',
#  'Dimethoate, mg/kg',
#  'Fenazaquin, mg/kg',
#  'Fenpropathrin, mg/kg',
#  'Fenpyroximate, mg/kg',
#  'Fipronil, mg/kg',
#  'Flubendiamide, mg/kg',
#  'Flusilazole, mg/kg',
#  'Hexaconazole, mg/kg',
#  'Hexythiazox, mg/kg',
#  'Imidacloprid, mg/kg',
#  'Indoxacarb, mg/kg',
#  'Kresoxim methyl, mg/kg',
#  'Lambda cyhalothrin, mg/kg',
#  'Lufenuron, mg/kg',
#  'Metalaxyl-M, mg/kg',
#  'Methomyl, mg/kg',
#  'Milbemectin, mg/kg',
#  'Monocrotophos, mg/kg',
#  'Myclobutanil, mg/kg',
#  'Novaluron, mg/kg',
#  'Oxydemeton methyl, mg/kg',
#  'Pendimethalin, mg/kg',
#  'Picoxystrobin, mg/kg',
#  'Propargite, mg/kg',
#  'Propineb, mg/kg',
#  'Pyraclostrobin, mg/kg',
#  'Pyridalyl, mg/kg',
#  'Pyriproxyfen, mg/kg',
#  'Quinalphos, mg/kg',
#  'Spinosad, mg/kg',
#  'Spiromesifen, mg/kg',
#  'Tebuconazole, mg/kg',
#  'Thiacloprid, mg/kg',
#  'Thiodicarb, mg/kg',
#  'Thiamethoxam, mg/kg',
#  'Triadimefon, mg/kg',
#  'Trifloxystrobin, mg/kg',
#  'Triazophos, mg/kg',
#  'Tricyclazole, mg/kg',
#  'Spinetoram and its metabolites\n(Spinosyn-J and Spinosyn-L), mg/kg',
#  'Spirotetramat, mg/kg',
#  'Abamectin, mg/kg',
#  'Dithiocarbamates (the residue tolerance limit are determined and expressed as mg/CS2/kg and refer separately to the residues arising from any or each group of dithiocarbamates)',
#  'Mancozeb, mg/kg',
#  'Metiram as CS2, mg/kg',
#  '(b) Ethylene bis- dithiocarbamates resulting from the use of mancozeb, maneb or zineb (including zineb derived from nabam plus zinc\nsulphate)',
#  '2,4-Dichlorophenoxy Acetic Acid',
#  'Acephate (expressed as mixture of Methamidophos and acephate).',
#  'Alachlor',
#  'Alpha cypermethrin',
#  'Ametroctradin',
#  'Anilophos',
#  'Atrazine',
#  'Azimsulfuron',
#  'Benfuracarb',
#  'Sum of benomyl and carbendazim expressed as carbendazim',
#  'Bensulfuron Methyl',
#  'Beta Cyfluthrin',
#  'Bifenthrin',
#  'Bispyribac Sodium',
#  'Bitertanol',
#  'Butachlor',
#  'Captan',
#  'Carbendazim',
#  'Carbofuran (sum of carbofuran and 3-hydroxy carbofuran expressed as carbofuran)',
#  'Carfentrazone Ethyl',
#  ...]

# %%
new_filter=filtered_names.copy()
new_filter += [el + " Compliance" for el in filtered_names]
new_filter = list(dict.fromkeys(new_filter))

# %%
new_filter
# Out:
# ['Acetamiprid, mg/kg',
#  'Alpha naphthyl Acetic Acid, mg/kg',
#  'Azoxystrobin, mg/kg',
#  'Buprofezin, mg/kg',
#  'Carbaryl, mg/kg',
#  'Carbosulfan, mg/kg',
#  'Chlorantraniliprole, mg/kg',
#  'Chlorfenapyr, mg/kg',
#  'Cuprous Oxide (Copper determined as elemental copper) mg/kg',
#  'Cyantranilipole, mg/kg',
#  'Deltamethrin/Decamethrin, mg/kg',
#  'Diafenthiuron, mg/kg',
#  'Dicofol (Sum of p,p and o,p isomers), mg/kg',
#  'Difenoconazole, mg/kg',
#  'Dimethoate, mg/kg',
#  'Fenazaquin, mg/kg',
#  'Fenpropathrin, mg/kg',
#  'Fenpyroximate, mg/kg',
#  'Fipronil, mg/kg',
#  'Flubendiamide, mg/kg',
#  'Flusilazole, mg/kg',
#  'Hexaconazole, mg/kg',
#  'Hexythiazox, mg/kg',
#  'Imidacloprid, mg/kg',
#  'Indoxacarb, mg/kg',
#  'Kresoxim methyl, mg/kg',
#  'Lambda cyhalothrin, mg/kg',
#  'Lufenuron, mg/kg',
#  'Methomyl, mg/kg',
#  'Milbemectin, mg/kg',
#  'Monocrotophos, mg/kg',
#  'Myclobutanil, mg/kg',
#  'Novaluron, mg/kg',
#  'Oxydemeton methyl, mg/kg',
#  'Pendimethalin, mg/kg',
#  'Picoxystrobin, mg/kg',
#  'Propargite, mg/kg',
#  'Propineb, mg/kg',
#  'Pyraclostrobin, mg/kg',
#  'Pyridalyl, mg/kg',
#  'Pyriproxyfen, mg/kg',
#  'Quinalphos, mg/kg',
#  'Spinosad, mg/kg',
#  'Spiromesifen, mg/kg',
#  'Tebuconazole, mg/kg',
#  'Thiacloprid, mg/kg',
#  'Thiodicarb, mg/kg',
#  'Thiamethoxam, mg/kg',
#  'Triadimefon, mg/kg',
#  'Trifloxystrobin, mg/kg',
#  'Triazophos, mg/kg',
#  'Tricyclazole, mg/kg',
#  'Spinetoram and its metabolites\n(Spinosyn-J and Spinosyn-L), mg/kg',
#  'Spirotetramat, mg/kg',
#  'Abamectin, mg/kg',
#  'Dithiocarbamates (the residue tolerance limit are determined and expressed as mg/CS2/kg and refer separately to the residues arising from any or each group of dithiocarbamates)',
#  'Metiram as CS2, mg/kg',
#  '(b) Ethylene bis- dithiocarbamates resulting from the use of mancozeb, maneb or zineb (including zineb derived from nabam plus zinc\nsulphate)',
#  '(e) Zineb as CS2',
#  '2,4-Dichlorophenoxy Acetic Acid',
#  'Acephate (expressed as mixture of Methamidophos and acephate).',
#  'Alachlor',
#  'Alpha cypermethrin',
#  'Ametroctradin',
#  'Anilophos',
#  'Atrazine',
#  'Azimsulfuron',
#  'Benfuracarb',
#  'Sum of benomyl and carbendazim expressed as carbendazim',
#  'Bensulfuron Methyl',
#  'Beta Cyfluthrin',
#  'Bifenthrin',
#  'Bispyribac Sodium',
#  'Bitertanol',
#  'Butachlor',
#  'Captan',
#  'Carbendazim',
#  'Carbofuran (sum of carbofuran and 3-hydroxy carbofuran expressed as carbofuran)',
#  'Carfentrazone Ethyl',
#  'Carpropamid',
#  'Cartap Hydrochloride',
#  'Chlorfluazuron',
#  'Chlorimuron ethyl',
#  'Chlormequat Chloride (CCC)',
#  'Chlorothalonil',
#  'Chlorpropham',
#  'Chlorpyriphos',
#  'Chlothianidin (Chlothianidin and its metabolites Thiazolymethylguanidine (TMG), Thiazolymethylurea (TZMU), Methylnitroguanidine (MNG) TMG)',
#  'Chromafenozide',
#  'Cinmethylene',
#  'Clodinafop-propargyl',
#  'Clomazone',
#  'Copper Hydroxide (Copper determined as elemental copper)',
#  'Copper Sulphate (Copper determined as elemental copper',
#  'Cyazofamid',
#  'Cyhalofop-butyl',
#  'Cymoxanil',
#  'Cypermethrin (sum of isomers) (Fat soluble residue)',
#  'Dichlorvos (DDVP) (content of di- chloroacetaldehyde (D.C.A.) be reported where possible)',
#  'Diclofop (sum diclofop-methyl and diclofop\nacid expressed as diclofop-methyl)”',
#  'Diclosulam',
#  'Diflubenzuron',
#  'Dimethomorph',
#  'Dinocap',
#  'Dinotefuran',
#  'Dithianon',
#  'Diuron',
#  'Dodine',
#  'Edifenphos',
#  'Emamectin Benzoate',
#  'Epoxyconazole, mg/kg',
#  'Ethephon',
#  'Ethion(Residues to be determined as ethion and its oxygen analogue and expressed as ethion)',
#  'Ethofenprox (Etofenprox)',
#  'Ethoxysulfuron',
#  'Etoxazole',
#  'Famoxadone',
#  'Fenamidone',
#  'Fenarimol',
#  'Fenobucarb (BPMC)',
#  'Fenoxaprop-p-ethyl',
#  'Fenvalerate (Fat soluble residue)',
#  'Flonicamid',
#  'Fluazifop-p-butyl',
#  'Fluchloralin',
#  'Flufenacet',
#  'Fluvalinate',
#  'Forchlorfenuron',
#  'Fosetyl-Al, mg/kg',
#  'Glufosinate Ammonium',
#  'Glyphosate',
#  'Halosulfuron methyl',
#  'Hexazinone',
#  'Hydrogen Cyanamide',
#  'Iodosulfuron Methyl Sodium',
#  'Imazethapyr',
#  'Iprobenfos (Kitazin)',
#  'Iprodione',
#  'Isoprothiolane',
#  'Isoproturon',
#  'Kasugamycin',
#  'Linuron',
#  'Malathion (Malathion to be determined and expressed as combined residues of malathion and malaoxon)',
#  'Mandipropamid',
#  'Mepiquat Chloride',
#  'Mesosulfuron Methyl',
#  'Metaflumizone',
#  'Metalaxyl',
#  'Methabenzthiazuron',
#  'Methyl Chlorophenoxy Acetic Acid (MCPA)',
#  'Methyl Parathion (combined residues of methyl parathion and its oxygen analogue to be determined and expressed as methyl parathion)',
#  'Metolachlor',
#  'Metribuzin',
#  'Metsulfuron Methyl',
#  'Orthosulfamuron',
#  'Oxadiargyl, mg/kg',
#  'Oxadiazon',
#  'Oxyfluorfen',
#  'Paclobutrazol',
#  'Paraquat dichloride (Determined as Paraquatcations)',
#  'Penconazole',
#  'Pencycuron',
#  'Penoxuslum',
#  'Permethrin',
#  'Phenthoate',
#  'Phorate (sum of Phorate, its oxygen analogue and their sulphoxides and sulphones, expressed as phorate)',
#  'Phosalone',
#  'Pinoxaden',
#  'Pretilachlor',
#  'Pirimiphos-methyl',
#  'Profenofos',
#  'Prohexadione calcium',
#  'Propaquizafop',
#  'Propiconazole',
#  'Pyrazosulfuron ethyl',
#  'Pyrithiolac Sodium',
#  'Pymetrozine',
#  'Quizalofop ethyl',
#  'Quizalofop-P-tefuryl',
#  'Sodium Aceflourofen',
#  'Sulfosulfuron',
#  'Thifluzamide',
#  'Thiometon(Residues determined as thiometon its sulfoxide and sulphone expressed as thiometon)',
#  'Thiophanate-Methyl',
#  'Tolfenpyrad',
#  'Trichlorfon',
#  'Triacontanol',
#  'Triallate',
#  'Triasulfuron',
#  'Tridemorph',
#  'Trifluralin',
#  'Validamycin',
#  'Fluopicolide',
#  'Tembotrione',
#  'Propanil',
#  'Fluopyram and its metabolites',
#  'Topramezone',
#  'Thiocyclam Hydrogen Oxalate',
#  '2,4-D Amine Salt',
#  'Ametyrn',
#  'Fomesafen',
#  'Imazamox',
#  'Sodium Para Nitro Phenolate',
#  'Bentazone',
#  'Cyflumetofen',
#  'Boscalid',
#  'Flucetosulfuron',
#  'Haloxyfop-R Methyl',
#  'Sulfentrazone and its metabolite Desmethylsulfentrazone and 3- Hydroxymethylsulfentrazone',
#  'Metrafenone',
#  'Fluxapyroxad',
#  'Tetraconazole',
#  'Flupyradifurone and its metabolites Difluroacetic Acid and Difluroethylamino- furanone',
#  'Sulfoxaflor',
#  'Aldicarb',
#  'Aldrin',
#  'Dieldrin',
#  'Chlordane',
#  'Heptalchlor',
#  'Lindane Gamma-HCH) Gamma (γ) Isomer (Known as Lindane)',
#  'Endosulfan',
#  'Phosphamidon',
#  'Captafol',
#  'Ferbam',
#  'Formothion',
#  'Simazine',
#  'Diazinon',
#  'D.D.T',
#  'Fenitrothion',
#  'Fenthion',
#  'Ethyl Parathion',
#  'Metalaxyl-M, mg/kg',
#  'Mancozeb, mg/kg',
#  'Copper Oxychloride (Copper determined as elemental copper), mg/ kg',
#  'Acetamiprid, mg/kg Compliance',
#  'Alpha naphthyl Acetic Acid, mg/kg Compliance',
#  'Azoxystrobin, mg/kg Compliance',
#  'Buprofezin, mg/kg Compliance',
#  'Carbaryl, mg/kg Compliance',
#  'Carbosulfan, mg/kg Compliance',
#  'Chlorantraniliprole, mg/kg Compliance',
#  'Chlorfenapyr, mg/kg Compliance',
#  'Cuprous Oxide (Copper determined as elemental copper) mg/kg Compliance',
#  'Cyantranilipole, mg/kg Compliance',
#  'Deltamethrin/Decamethrin, mg/kg Compliance',
#  'Diafenthiuron, mg/kg Compliance',
#  'Dicofol (Sum of p,p and o,p isomers), mg/kg Compliance',
#  'Difenoconazole, mg/kg Compliance',
#  'Dimethoate, mg/kg Compliance',
#  'Fenazaquin, mg/kg Compliance',
#  'Fenpropathrin, mg/kg Compliance',
#  'Fenpyroximate, mg/kg Compliance',
#  'Fipronil, mg/kg Compliance',
#  'Flubendiamide, mg/kg Compliance',
#  'Flusilazole, mg/kg Compliance',
#  'Hexaconazole, mg/kg Compliance',
#  'Hexythiazox, mg/kg Compliance',
#  'Imidacloprid, mg/kg Compliance',
#  'Indoxacarb, mg/kg Compliance',
#  'Kresoxim methyl, mg/kg Compliance',
#  'Lambda cyhalothrin, mg/kg Compliance',
#  'Lufenuron, mg/kg Compliance',
#  'Methomyl, mg/kg Compliance',
#  'Milbemectin, mg/kg Compliance',
#  'Monocrotophos, mg/kg Compliance',
#  'Myclobutanil, mg/kg Compliance',
#  'Novaluron, mg/kg Compliance',
#  'Oxydemeton methyl, mg/kg Compliance',
#  'Pendimethalin, mg/kg Compliance',
#  'Picoxystrobin, mg/kg Compliance',
#  'Propargite, mg/kg Compliance',
#  'Propineb, mg/kg Compliance',
#  'Pyraclostrobin, mg/kg Compliance',
#  'Pyridalyl, mg/kg Compliance',
#  'Pyriproxyfen, mg/kg Compliance',
#  'Quinalphos, mg/kg Compliance',
#  'Spinosad, mg/kg Compliance',
#  'Spiromesifen, mg/kg Compliance',
#  'Tebuconazole, mg/kg Compliance',
#  'Thiacloprid, mg/kg Compliance',
#  'Thiodicarb, mg/kg Compliance',
#  'Thiamethoxam, mg/kg Compliance',
#  'Triadimefon, mg/kg Compliance',
#  'Trifloxystrobin, mg/kg Compliance',
#  'Triazophos, mg/kg Compliance',
#  'Tricyclazole, mg/kg Compliance',
#  'Spinetoram and its metabolites\n(Spinosyn-J and Spinosyn-L), mg/kg Compliance',
#  'Spirotetramat, mg/kg Compliance',
#  'Abamectin, mg/kg Compliance',
#  'Dithiocarbamates (the residue tolerance limit are determined and expressed as mg/CS2/kg and refer separately to the residues arising from any or each group of dithiocarbamates) Compliance',
#  'Metiram as CS2, mg/kg Compliance',
#  '(b) Ethylene bis- dithiocarbamates resulting from the use of mancozeb, maneb or zineb (including zineb derived from nabam plus zinc\nsulphate) Compliance',
#  '(e) Zineb as CS2 Compliance',
#  '2,4-Dichlorophenoxy Acetic Acid Compliance',
#  'Acephate (expressed as mixture of Methamidophos and acephate). Compliance',
#  'Alachlor Compliance',
#  'Alpha cypermethrin Compliance',
#  'Ametroctradin Compliance',
#  'Anilophos Compliance',
#  'Atrazine Compliance',
#  'Azimsulfuron Compliance',
#  'Benfuracarb Compliance',
#  'Sum of benomyl and carbendazim expressed as carbendazim Compliance',
#  'Bensulfuron Methyl Compliance',
#  'Beta Cyfluthrin Compliance',
#  'Bifenthrin Compliance',
#  'Bispyribac Sodium Compliance',
#  'Bitertanol Compliance',
#  'Butachlor Compliance',
#  'Captan Compliance',
#  'Carbendazim Compliance',
#  'Carbofuran (sum of carbofuran and 3-hydroxy carbofuran expressed as carbofuran) Compliance',
#  'Carfentrazone Ethyl Compliance',
#  'Carpropamid Compliance',
#  'Cartap Hydrochloride Compliance',
#  'Chlorfluazuron Compliance',
#  'Chlorimuron ethyl Compliance',
#  'Chlormequat Chloride (CCC) Compliance',
#  'Chlorothalonil Compliance',
#  'Chlorpropham Compliance',
#  'Chlorpyriphos Compliance',
#  'Chlothianidin (Chlothianidin and its metabolites Thiazolymethylguanidine (TMG), Thiazolymethylurea (TZMU), Methylnitroguanidine (MNG) TMG) Compliance',
#  'Chromafenozide Compliance',
#  'Cinmethylene Compliance',
#  'Clodinafop-propargyl Compliance',
#  'Clomazone Compliance',
#  'Copper Hydroxide (Copper determined as elemental copper) Compliance',
#  'Copper Sulphate (Copper determined as elemental copper Compliance',
#  'Cyazofamid Compliance',
#  'Cyhalofop-butyl Compliance',
#  'Cymoxanil Compliance',
#  'Cypermethrin (sum of isomers) (Fat soluble residue) Compliance',
#  'Dichlorvos (DDVP) (content of di- chloroacetaldehyde (D.C.A.) be reported where possible) Compliance',
#  'Diclofop (sum diclofop-methyl and diclofop\nacid expressed as diclofop-methyl)” Compliance',
#  'Diclosulam Compliance',
#  'Diflubenzuron Compliance',
#  'Dimethomorph Compliance',
#  'Dinocap Compliance',
#  'Dinotefuran Compliance',
#  'Dithianon Compliance',
#  'Diuron Compliance',
#  'Dodine Compliance',
#  'Edifenphos Compliance',
#  'Emamectin Benzoate Compliance',
#  'Epoxyconazole, mg/kg Compliance',
#  'Ethephon Compliance',
#  'Ethion(Residues to be determined as ethion and its oxygen analogue and expressed as ethion) Compliance',
#  'Ethofenprox (Etofenprox) Compliance',
#  'Ethoxysulfuron Compliance',
#  'Etoxazole Compliance',
#  'Famoxadone Compliance',
#  'Fenamidone Compliance',
#  'Fenarimol Compliance',
#  'Fenobucarb (BPMC) Compliance',
#  'Fenoxaprop-p-ethyl Compliance',
#  'Fenvalerate (Fat soluble residue) Compliance',
#  'Flonicamid Compliance',
#  'Fluazifop-p-butyl Compliance',
#  'Fluchloralin Compliance',
#  'Flufenacet Compliance',
#  'Fluvalinate Compliance',
#  'Forchlorfenuron Compliance',
#  'Fosetyl-Al, mg/kg Compliance',
#  'Glufosinate Ammonium Compliance',
#  'Glyphosate Compliance',
#  'Halosulfuron methyl Compliance',
#  'Hexazinone Compliance',
#  'Hydrogen Cyanamide Compliance',
#  'Iodosulfuron Methyl Sodium Compliance',
#  'Imazethapyr Compliance',
#  'Iprobenfos (Kitazin) Compliance',
#  'Iprodione Compliance',
#  'Isoprothiolane Compliance',
#  'Isoproturon Compliance',
#  'Kasugamycin Compliance',
#  'Linuron Compliance',
#  'Malathion (Malathion to be determined and expressed as combined residues of malathion and malaoxon) Compliance',
#  'Mandipropamid Compliance',
#  'Mepiquat Chloride Compliance',
#  'Mesosulfuron Methyl Compliance',
#  'Metaflumizone Compliance',
#  'Metalaxyl Compliance',
#  'Methabenzthiazuron Compliance',
#  'Methyl Chlorophenoxy Acetic Acid (MCPA) Compliance',
#  'Methyl Parathion (combined residues of methyl parathion and its oxygen analogue to be determined and expressed as methyl parathion) Compliance',
#  'Metolachlor Compliance',
#  'Metribuzin Compliance',
#  'Metsulfuron Methyl Compliance',
#  'Orthosulfamuron Compliance',
#  'Oxadiargyl, mg/kg Compliance',
#  'Oxadiazon Compliance',
#  'Oxyfluorfen Compliance',
#  'Paclobutrazol Compliance',
#  'Paraquat dichloride (Determined as Paraquatcations) Compliance',
#  'Penconazole Compliance',
#  'Pencycuron Compliance',
#  'Penoxuslum Compliance',
#  'Permethrin Compliance',
#  'Phenthoate Compliance',
#  'Phorate (sum of Phorate, its oxygen analogue and their sulphoxides and sulphones, expressed as phorate) Compliance',
#  'Phosalone Compliance',
#  'Pinoxaden Compliance',
#  'Pretilachlor Compliance',
#  'Pirimiphos-methyl Compliance',
#  'Profenofos Compliance',
#  'Prohexadione calcium Compliance',
#  'Propaquizafop Compliance',
#  'Propiconazole Compliance',
#  'Pyrazosulfuron ethyl Compliance',
#  'Pyrithiolac Sodium Compliance',
#  'Pymetrozine Compliance',
#  'Quizalofop ethyl Compliance',
#  'Quizalofop-P-tefuryl Compliance',
#  'Sodium Aceflourofen Compliance',
#  'Sulfosulfuron Compliance',
#  'Thifluzamide Compliance',
#  'Thiometon(Residues determined as thiometon its sulfoxide and sulphone expressed as thiometon) Compliance',
#  'Thiophanate-Methyl Compliance',
#  'Tolfenpyrad Compliance',
#  'Trichlorfon Compliance',
#  'Triacontanol Compliance',
#  'Triallate Compliance',
#  'Triasulfuron Compliance',
#  'Tridemorph Compliance',
#  'Trifluralin Compliance',
#  'Validamycin Compliance',
#  'Fluopicolide Compliance',
#  'Tembotrione Compliance',
#  'Propanil Compliance',
#  'Fluopyram and its metabolites Compliance',
#  'Topramezone Compliance',
#  'Thiocyclam Hydrogen Oxalate Compliance',
#  '2,4-D Amine Salt Compliance',
#  'Ametyrn Compliance',
#  'Fomesafen Compliance',
#  'Imazamox Compliance',
#  'Sodium Para Nitro Phenolate Compliance',
#  'Bentazone Compliance',
#  'Cyflumetofen Compliance',
#  'Boscalid Compliance',
#  'Flucetosulfuron Compliance',
#  'Haloxyfop-R Methyl Compliance',
#  'Sulfentrazone and its metabolite Desmethylsulfentrazone and 3- Hydroxymethylsulfentrazone Compliance',
#  'Metrafenone Compliance',
#  'Fluxapyroxad Compliance',
#  'Tetraconazole Compliance',
#  'Flupyradifurone and its metabolites Difluroacetic Acid and Difluroethylamino- furanone Compliance',
#  'Sulfoxaflor Compliance',
#  'Aldicarb Compliance',
#  'Aldrin Compliance',
#  'Dieldrin Compliance',
#  'Chlordane Compliance',
#  'Heptalchlor Compliance',
#  'Lindane Gamma-HCH) Gamma (γ) Isomer (Known as Lindane) Compliance',
#  'Endosulfan Compliance',
#  'Phosphamidon Compliance',
#  'Captafol Compliance',
#  'Ferbam Compliance',
#  'Formothion Compliance',
#  'Simazine Compliance',
#  'Diazinon Compliance',
#  'D.D.T Compliance',
#  'Fenitrothion Compliance',
#  'Fenthion Compliance',
#  'Ethyl Parathion Compliance',
#  'Metalaxyl-M, mg/kg Compliance',
#  'Mancozeb, mg/kg Compliance',
#  'Copper Oxychloride (Copper determined as elemental copper), mg/ kg Compliance']

# %%
# filtered_names += [col + " Compliance" for col in filtered_names if col + " Compliance" in df_new.columns]

# %%
# filtered_names

# %%
filtered_names
len(filtered_names)

len(new_filter)
# Out:
# 468

# %%
# first_20_columns = df_new.columns[:19].tolist()

# # Get the columns from the 21st onward that match filtered names or their "Compliance" versions
# # filtered_columns = [col for col in df_new.columns[20:] if col in filtered_names or col + " Compliance" in filtered_names]

# # Combine both lists
# columns_to_keep = first_20_columns + new_filter

# # Keep only the selected columns
# df_filtered = df_new.loc[:, columns_to_keep]

# %%
first_20_columns = df_new.columns[:19].tolist()


# Combine both lists
columns_to_keep = first_20_columns + new_filter
columns_to_keep = [col for col in columns_to_keep if col in df_new.columns]

# Keep only the selected columns
df_filtered = df_new.loc[:, columns_to_keep]

# %%
df_filtered
# Out:
#                                Order ID                    Category  \
# 0                               orderId                    category
# 1   FS-AP-AN-BLACK_PEPPER_POWDER-034810  Herbs, Spices & Condiments
# 2        FS-AP-AN-CARDAMON_WHOLE-089865  Herbs, Spices & Condiments
# 3        FS-AP-AN-CARDAMON_WHOLE-717782  Herbs, Spices & Condiments
# 4       FS-AP-AN-CORIANDER_WHOLE-414781  Herbs, Spices & Condiments
# ..                                  ...                         ...
# 94        FS-AS-GU-CHILLI_POWDER-168424  Herbs, Spices & Condiments
# 95         FS-AS-GU-CHILLI_WHOLE-862443  Herbs, Spices & Condiments
# 96         FS-AS-GU-CHILLI_WHOLE-916138  Herbs, Spices & Condiments
# 97     FS-AS-GU-CORIANDER_POWDER-576000  Herbs, Spices & Condiments
# 98     FS-AS-GU-CORIANDER_POWDER-836007  Herbs, Spices & Condiments
#
#               Commodity           State   District        Type        Variant  \
# 0             commodity           state   district  sampleType  sampleVariant
# 1   Black Pepper Powder  Andhra Pradesh  Anantapur      Powder         Normal
# 2        Cardamon Whole  Andhra Pradesh  Anantapur       Whole         Normal
# 3        Cardamon Whole  Andhra Pradesh  Anantapur       Whole         Normal
# 4       Coriander Whole  Andhra Pradesh  Anantapur       Whole         Normal
# ..                  ...             ...        ...         ...            ...
# 94        Chilli Powder           Assam   Guwahati      Powder         Normal
# 95         Chilli whole           Assam   Guwahati       Whole         Normal
# 96         Chilli whole           Assam   Guwahati       Whole          Loose
# 97     Coriander Powder           Assam   Guwahati      Powder         Normal
# 98     Coriander Powder           Assam   Guwahati      Powder         Normal
#
#    Lab Report Link                                          Lab Name  \
# 0    labReportLink                                               NaN
# 1              NaN                                Vimta Labs Limited
# 2              NaN                                Vimta Labs Limited
# 3              NaN                                Vimta Labs Limited
# 4              NaN                                Vimta Labs Limited
# ..             ...                                               ...
# 94             NaN  Edward Food Research and Analysis Centre Limited
# 95             NaN  Edward Food Research and Analysis Centre Limited
# 96             NaN  Edward Food Research and Analysis Centre Limited
# 97             NaN  Edward Food Research and Analysis Centre Limited
# 98             NaN  Edward Food Research and Analysis Centre Limited
#
#     Unnamed: 9  ... Formothion Compliance  Simazine Compliance  \
# 0          NaN  ...                   NaN                  NaN
# 1          NaN  ...                  Safe                 Safe
# 2          NaN  ...                  Safe                 Safe
# 3          NaN  ...                  Safe                 Safe
# 4          NaN  ...                  Safe                 Safe
# ..         ...  ...                   ...                  ...
# 94         NaN  ...                  Safe                 Safe
# 95         NaN  ...                  Safe                 Safe
# 96         NaN  ...                  Safe                 Safe
# 97         NaN  ...                  Safe                 Safe
# 98         NaN  ...                  Safe                 Safe
#
#     Diazinon Compliance  D.D.T Compliance  Fenitrothion Compliance  \
# 0                   NaN               NaN                      NaN
# 1                  Safe              Safe                     Safe
# 2                  Safe              Safe                     Safe
# 3                  Safe              Safe                     Safe
# 4                  Safe              Safe                     Safe
# ..                  ...               ...                      ...
# 94                 Safe              Safe                     Safe
# 95                 Safe              Safe                     Safe
# 96                 Safe              Safe                     Safe
# 97                 Safe              Safe                     Safe
# 98                 Safe              Safe                     Safe
#
#     Fenthion Compliance  Ethyl Parathion Compliance  \
# 0                   NaN                         NaN
# 1                  Safe                        Safe
# 2                  Safe                        Safe
# 3                  Safe                        Safe
# 4                  Safe                        Safe
# ..                  ...                         ...
# 94                 Safe                        Safe
# 95                 Safe                        Safe
# 96                 Safe                        Safe
# 97                 Safe                        Safe
# 98                 Safe                        Safe
#
#     Metalaxyl-M, mg/kg Compliance  Mancozeb, mg/kg Compliance  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                            Safe                         NaN
# 3                            Safe                         NaN
# 4                            Safe                         NaN
# ..                            ...                         ...
# 94                            NaN                         NaN
# 95                            NaN                         NaN
# 96                            NaN                         NaN
# 97                           Safe                        Safe
# 98                           Safe                        Safe
#
#    Copper Oxychloride (Copper determined as elemental copper), mg/ kg Compliance
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                              Unsafe
# ..                                                ...
# 94                                             Unsafe
# 95                                             Unsafe
# 96                                             Unsafe
# 97                                             Unsafe
# 98                                             Unsafe
#
# [99 rows x 483 columns]

# %%
df_new
# Out:
#                                Order ID                    Category  \
# 0                               orderId                    category
# 1   FS-AP-AN-BLACK_PEPPER_POWDER-034810  Herbs, Spices & Condiments
# 2        FS-AP-AN-CARDAMON_WHOLE-089865  Herbs, Spices & Condiments
# 3        FS-AP-AN-CARDAMON_WHOLE-717782  Herbs, Spices & Condiments
# 4       FS-AP-AN-CORIANDER_WHOLE-414781  Herbs, Spices & Condiments
# ..                                  ...                         ...
# 94        FS-AS-GU-CHILLI_POWDER-168424  Herbs, Spices & Condiments
# 95         FS-AS-GU-CHILLI_WHOLE-862443  Herbs, Spices & Condiments
# 96         FS-AS-GU-CHILLI_WHOLE-916138  Herbs, Spices & Condiments
# 97     FS-AS-GU-CORIANDER_POWDER-576000  Herbs, Spices & Condiments
# 98     FS-AS-GU-CORIANDER_POWDER-836007  Herbs, Spices & Condiments
#
#               Commodity           State   District        Type        Variant  \
# 0             commodity           state   district  sampleType  sampleVariant
# 1   Black Pepper Powder  Andhra Pradesh  Anantapur      Powder         Normal
# 2        Cardamon Whole  Andhra Pradesh  Anantapur       Whole         Normal
# 3        Cardamon Whole  Andhra Pradesh  Anantapur       Whole         Normal
# 4       Coriander Whole  Andhra Pradesh  Anantapur       Whole         Normal
# ..                  ...             ...        ...         ...            ...
# 94        Chilli Powder           Assam   Guwahati      Powder         Normal
# 95         Chilli whole           Assam   Guwahati       Whole         Normal
# 96         Chilli whole           Assam   Guwahati       Whole          Loose
# 97     Coriander Powder           Assam   Guwahati      Powder         Normal
# 98     Coriander Powder           Assam   Guwahati      Powder         Normal
#
#    Lab Report Link                                          Lab Name  \
# 0    labReportLink                                               NaN
# 1              NaN                                Vimta Labs Limited
# 2              NaN                                Vimta Labs Limited
# 3              NaN                                Vimta Labs Limited
# 4              NaN                                Vimta Labs Limited
# ..             ...                                               ...
# 94             NaN  Edward Food Research and Analysis Centre Limited
# 95             NaN  Edward Food Research and Analysis Centre Limited
# 96             NaN  Edward Food Research and Analysis Centre Limited
# 97             NaN  Edward Food Research and Analysis Centre Limited
# 98             NaN  Edward Food Research and Analysis Centre Limited
#
#     Unnamed: 9  ... Unnamed: 676  No of Submissions  \
# 0          NaN  ...          NaN                NaN
# 1          NaN  ...          NaN                NaN
# 2          NaN  ...          NaN                NaN
# 3          NaN  ...          NaN                NaN
# 4          NaN  ...          NaN                NaN
# ..         ...  ...          ...                ...
# 94         NaN  ...          NaN                NaN
# 95         NaN  ...          NaN                NaN
# 96         NaN  ...          NaN                NaN
# 97         NaN  ...          NaN                NaN
# 98         NaN  ...          NaN                NaN
#
#         Banned Pesticide List  Failed in Quality Parameters  \
# 0                         NaN                           NaN
# 1   No Failed Parameter Found     No Failed Parameter Found
# 2   No Failed Parameter Found     No Failed Parameter Found
# 3   No Failed Parameter Found     No Failed Parameter Found
# 4   No Failed Parameter Found     No Failed Parameter Found
# ..                        ...                           ...
# 94  No Failed Parameter Found     No Failed Parameter Found
# 95  No Failed Parameter Found     No Failed Parameter Found
# 96  No Failed Parameter Found     No Failed Parameter Found
# 97  No Failed Parameter Found     No Failed Parameter Found
# 98  No Failed Parameter Found     No Failed Parameter Found
#
#     Failed in Crop Contaminants  Failed in Metal Contaminants  \
# 0                           NaN                           NaN
# 1     No Failed Parameter Found     No Failed Parameter Found
# 2     No Failed Parameter Found     No Failed Parameter Found
# 3     No Failed Parameter Found     No Failed Parameter Found
# 4     No Failed Parameter Found     No Failed Parameter Found
# ..                          ...                           ...
# 94    No Failed Parameter Found     No Failed Parameter Found
# 95    No Failed Parameter Found     No Failed Parameter Found
# 96    No Failed Parameter Found     No Failed Parameter Found
# 97    No Failed Parameter Found     No Failed Parameter Found
# 98    No Failed Parameter Found     No Failed Parameter Found
#
#                           Failed in Pesticide Residue  \
# 0                                                 NaN
# 1                                 Hexaconazole, mg/kg
# 2   Cuprous Oxide (Copper determined as elemental ...
# 3                           No Failed Parameter Found
# 4   Copper Oxychloride (Copper determined as eleme...
# ..                                                ...
# 94  Copper Oxychloride (Copper determined as eleme...
# 95  Copper Oxychloride (Copper determined as eleme...
# 96  Copper Oxychloride (Copper determined as eleme...
# 97  Copper Oxychloride (Copper determined as eleme...
# 98  Copper Oxychloride (Copper determined as eleme...
#
#        Failed in Microbiology      Failed in Adulterants  \
# 0                         NaN                        NaN
# 1   No Failed Parameter Found  No Failed Parameter Found
# 2   No Failed Parameter Found  No Failed Parameter Found
# 3   No Failed Parameter Found  No Failed Parameter Found
# 4   No Failed Parameter Found  No Failed Parameter Found
# ..                        ...                        ...
# 94  No Failed Parameter Found  No Failed Parameter Found
# 95  No Failed Parameter Found  No Failed Parameter Found
# 96  No Failed Parameter Found  No Failed Parameter Found
# 97  No Failed Parameter Found  No Failed Parameter Found
# 98  No Failed Parameter Found  No Failed Parameter Found
#
#                             OverAll Failed Parameters
# 0                                                 NaN
# 1                                 Hexaconazole, mg/kg
# 2   Cuprous Oxide (Copper determined as elemental ...
# 3                           No Failed Parameter Found
# 4   Copper Oxychloride (Copper determined as eleme...
# ..                                                ...
# 94  Copper Oxychloride (Copper determined as eleme...
# 95  Copper Oxychloride (Copper determined as eleme...
# 96  Copper Oxychloride (Copper determined as eleme...
# 97  Copper Oxychloride (Copper determined as eleme...
# 98  Copper Oxychloride (Copper determined as eleme...
#
# [99 rows x 686 columns]

# %%
df=df_filtered.copy()
df.shape
# df
# Out:
# (99, 483)

# %%
# df = df.drop_duplicates(subset=['Order ID'])
# df

# %%
# Read the Excel file

# Define the start and end column names
start_column = 'Acetamiprid, mg/kg'
end_column = 'Copper Oxychloride (Copper determined as elemental copper), mg/ kg'

# Get all column names
# Get all column names
# Clean column names (remove leading/trailing spaces and newlines)
# Get all column names
columns = df.columns.tolist()

# Find the index of start and end columns
start_col = columns.index(start_column)
end_col = columns.index(end_column)

# Create a list of columns between start and end columns (inclusive)
param_columns = columns[start_col:end_col + 1]

# For each parameter column, insert a new FSSR Limits column right after it
for col in param_columns:
    # Get the position of the current column
    col_idx = df.columns.get_loc(col)
    # Create new column name
    new_col_name = f"FSSR Limits {col}"
    # Insert empty column after the parameter column
    df.insert(col_idx + 1, new_col_name, '')

# Save the modified DataFrame back to Excel
df.to_excel('a.xlsx', sheet_name='Sheet1', index=False)
print("Successfully added FSSR Limits columns")
# Out:
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\11755275.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(col_idx + 1, new_col_name, '')
# Successfully added FSSR Limits columns

# %% [markdown]
# this is olve use case of rohan

# %%
# # Define the commodity mappings
# commodity_mappings = {
#     "Black Pepper Whole": [
#         "Diameter,mm", "Piperine Content (on dry basis),%", "Volatile oil on dry basis, %",
#         "Non-volatile ether extract on dry basis, %", "Bulk density, g/l"
#     ],
#     "Black Pepper Powder": [
#         "Piperine Content (on dry basis),%", "Volatile oil on dry basis, %", 
#         "Non-volatile ether extract on dry basis, %"
#     ],
#     "Cardamom powder": ["Volatile oil on dry basis, %"],
#     "Cardamon Whole": ["Volatile oil on dry basis, %"],
#     "Turmeric Powder": ["Colouring power expressed as curcuminoid content on dry basis, %"],
#     "Chilli Powder": ["Non-volatile ether extract on dry basis, %"],
#     "Coriander Whole": ["Volatile oil on dry basis, %"],
#     "Coriander Powder": ["Volatile oil on dry basis, %"],
#     "Cumin Powder": ["Volatile oil on dry basis, %"],
#     "Cumin Whole": ["Volatile oil content, ml/100g"]
# }

# # Read the updated Excel file
# df = pd.read_excel('param_updated.xlsx')

# # Function to determine if a parameter should have Min value
# def should_be_min(commodity, parameter):
#     if commodity in commodity_mappings:
#         return parameter in commodity_mappings[commodity]
#     return False

# # Iterate through each row in the DataFrame
# for idx, row in df.iterrows():
#     commodity = row['Commodity']
    
#     # Get all columns except 'Commodity'
#     param_columns = [col for col in df.columns if col != 'Commodity']
    
#     # Update each parameter column
#     for col in param_columns:
#         # Check if it's a parameter column (not a FSSR Limits column)
#         if not col.startswith('FSSR Limits'):
#             if should_be_min(commodity, col):
#                 df.at[idx, f'FSSR Limits {col}'] = 'Min'
#             else:
#                 df.at[idx, f'FSSR Limits {col}'] = 'Max'

# # Save the updated DataFrame
# df.to_excel('param_updated_with_limits.xlsx', index=False)
# print("Successfully updated FSSR Limits columns with Min/Max values")

# %%
# Read the updated Excel file
import pandas as pd
df = pd.read_excel('a.xlsx')

# Iterate through each row in the DataFrame
for idx, row in df.iterrows():
    commodity = row['Commodity']
    
    # Get all columns except 'Commodity'
    param_columns = [col for col in df.columns if col != 'Commodity']
    
    # Update each parameter column
    for col in param_columns:
        # Check if it's a parameter column (not a FSSR Limits column)
        if not col.startswith('FSSR Limits'):
            df.at[idx, f'FSSR Limits {col}'] = 'Max'

# Save the updated DataFrame
df.to_excel('b.xlsx', index=False)
print("Successfully updated FSSR Limits columns with Max values")
# Out:
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Max' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# ...
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# C:\Users\rohan\AppData\Local\Temp\ipykernel_20592\1125748493.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, f'FSSR Limits {col}'] = 'Max'
# Successfully updated FSSR Limits columns with Max values

# %%
# import pandas as pd
# import multiprocessing as mp
# import numpy as np
# # Define the commodity mappings
# commodity_mappings = {
#     "Black Pepper Whole": [
#         "Diameter,mm", "Piperine Content (on dry basis),%", "Volatile oil on dry basis, %",
#         "Non-volatile ether extract on dry basis, %", "Bulk density, g/l"
#     ],
#     "Black Pepper Powder": [
#         "Piperine Content (on dry basis),%", "Volatile oil on dry basis, %", 
#         "Non-volatile ether extract on dry basis, %"
#     ],
#     "Cardamom powder": ["Volatile oil on dry basis, %"],
#     "Cardamon Whole": ["Volatile oil on dry basis, %"],
#     "Turmeric Powder": ["Colouring power expressed as curcuminoid content on dry basis, %"],
#     "Chilli Powder": ["Non-volatile ether extract on dry basis, %"],
#     "Coriander Whole": ["Volatile oil on dry basis, %"],
#     "Coriander Powder": ["Volatile oil on dry basis, %"],
#     "Cumin Powder": ["Volatile oil on dry basis, %"],
#     "Cumin Whole": ["Volatile oil content, ml/100g"]
# }

# # Read the updated Excel file
# df = pd.read_excel('param_updated.xlsx')

# # Function to determine if a parameter should have Min value
# def should_be_min(commodity, parameter):
#     if commodity in commodity_mappings:
#         return parameter in commodity_mappings[commodity]
#     return False

# # Function to process a chunk of data
# def process_chunk(df_chunk):
#     for idx, row in df_chunk.iterrows():
#         commodity = row['Commodity']
        
#         # Get all columns except 'Commodity'
#         param_columns = [col for col in df_chunk.columns if col != 'Commodity']
        
#         # Update each parameter column
#         for col in param_columns:
#             if not col.startswith('FSSR Limits'):
#                 if should_be_min(commodity, col):
#                     df_chunk.at[idx, f'FSSR Limits {col}'] = 'Min'
#                 else:
#                     df_chunk.at[idx, f'FSSR Limits {col}'] = 'Max'
    
#     return df_chunk

# # Number of processes
# num_processes = mp.cpu_count()  # Use all available cores

# # Split the DataFrame into chunks
# df_split = np.array_split(df, num_processes)

# # Use multiprocessing Pool to process the chunks in parallel
# with mp.Pool(num_processes) as pool:
#     df_chunks_processed = pool.map(process_chunk, df_split)

# # Merge all processed chunks back into a single DataFrame
# df_final = pd.concat(df_chunks_processed)

# # Save the updated DataFrame
# df_final.to_excel('param_updated_with_limits2.xlsx', index=False)
# print("Successfully updated FSSR Limits columns with Min/Max values using multiprocessing")

# %% [markdown]
# this is the olve logic of rohan usecase

# %%
# # Read both sheets from the Excel file
# df_sheet1 = pd.read_excel('param_updated_with_limits.xlsx')
# # df_master = pd.read_excel('Master.xlsx', sheet_name='Parameters Details')
# df_master=df_new_Master

# # Define the commodity mappings for Min values
# commodity_mappings = {
#     "Black Pepper Whole": [
#         "Diameter,mm", "Piperine Content (on dry basis),%", "Volatile oil on dry basis, %",
#         "Non-volatile ether extract on dry basis, %", "Bulk density, g/l"
#     ],
#     "Black Pepper Powder": [
#         "Piperine Content (on dry basis),%", "Volatile oil on dry basis, %", 
#         "Non-volatile ether extract on dry basis, %"
#     ],
#     "Cardamom powder": ["Volatile oil on dry basis, %"],
#     "Cardamon Whole": ["Volatile oil on dry basis, %"],
#     "Turmeric Powder": ["Colouring power expressed as curcuminoid content on dry basis, %"],
#     "Chilli Powder": ["Non-volatile ether extract on dry basis, %"],
#     "Coriander Whole": ["Volatile oil on dry basis, %"],
#     "Coriander Powder": ["Volatile oil on dry basis, %"],
#     "Cumin Powder": ["Volatile oil on dry basis, %"],
#     "Cumin Whole": ["Volatile oil content, ml/100g"]
# }

# # Function to get the appropriate value from Master sheet
# def get_master_value(commodity, parameter, variant, limit_type='Min'):
#     # Find matching row in master sheet
#     master_row = df_master[(df_master['Commodity'] == commodity) & 
#                           (df_master['Parameter'] == parameter)]
    
#     if not master_row.empty:
#         if variant in ['Loose', 'Normal']:
#             if limit_type == 'Min':
#                 value = master_row['Min FSSAI Acceptable Value'].iloc[0]
#             else:  # Max
#                 value = master_row['Max FSSAI Acceptable Value'].iloc[0]
#         elif variant == 'Organic':
#             if limit_type == 'Min':
#                 value = master_row['Min FSSAI Acceptable Value - Organic'].iloc[0]
#             else:  # Max
#                 value = master_row['Max FSSAI Acceptable Value - Organic'].iloc[0]
#         else:
#             return None
        
#         # Convert to string and handle NaN
#         if pd.isna(value):
#             return None
#         return str(value)
#     return None

# # Iterate through each row in Sheet1
# for idx, row in df_sheet1.iterrows():
#     commodity = row['Commodity']
#     variant = row['Variant']
    
#     # Process all columns except 'Commodity' and 'Variant'
#     param_columns = [col for col in df_sheet1.columns if col not in ['Commodity', 'Variant'] 
#                     and not col.startswith('FSSR Limits')]
    
#     for param in param_columns:
#         fssr_col = f'FSSR Limits {param}'
#         current_limit = df_sheet1.at[idx, fssr_col]
        
#         # Determine if this is a Min or Max parameter
#         is_min = False
#         if commodity in commodity_mappings:
#             is_min = param in commodity_mappings[commodity]
        
#         # Get value from master sheet based on limit type
#         master_value = get_master_value(commodity, param, variant, 'Min' if is_min else 'Max')
        
#         if master_value is not None:
#             # Update the FSSR Limits column with Min/Max and the value
#             df_sheet1.at[idx, fssr_col] = f"{current_limit} {master_value}"

# # Save the updated DataFrame

# df_sheet1.to_excel('param_updated_with_all_limits_and_values.xlsx', index=False)
# print("Successfully updated all FSSR Limits columns with values from Master sheet")

# %%
# # Read both sheets from the Excel file
# import pandas as pd

# df_sheet1 = pd.read_excel('param_updated_with_limits.xlsx')
# df_master = df_new_Master

# # Function to get the appropriate value from Master sheet
# def get_master_value(commodity, parameter, variant, limit_type='Max'):
#     # Find matching row in master sheet
#     master_row = df_master[(df_master['Commodity'] == commodity) & 
#                           (df_master['Parameter'] == parameter)]
    
#     if not master_row.empty:
#         if variant in ['Loose', 'Normal']:
#             value = master_row['Max FSSAI Acceptable Value'].iloc[0]
#         elif variant == 'Organic':
#             value = master_row['Max FSSAI Acceptable Value - Organic'].iloc[0]
#         else:
#             return None
        
#         # Convert to string and handle NaN
#         if pd.isna(value):
#             return None
#         return str(value)
#     return None

# # Iterate through each row in Sheet1
# for idx, row in df_sheet1.iterrows():
#     commodity = row['Commodity']
#     variant = row['Variant']
    
#     # Process all columns except 'Commodity' and 'Variant'
#     param_columns = [col for col in df_sheet1.columns if col not in ['Commodity', 'Variant'] 
#                     and not col.startswith('FSSR Limits')]
    
#     for param in param_columns:
#         fssr_col = f'FSSR Limits {param}'
#         current_limit = df_sheet1.at[idx, fssr_col]
        
#         # Always use 'Max' as limit type
#         master_value = get_master_value(commodity, param, variant, 'Max')
        
#         if master_value is not None:
#             # Update the FSSR Limits column with Max value
#             df_sheet1.at[idx, fssr_col] = f"{current_limit} {master_value}"

# # Save the updated DataFrame
# df_sheet1.to_excel('param_updated_with_all_limits_and_values.xlsx', index=False)
# print("Successfully updated all FSSR Limits columns with values from Master sheet")

# %%
# Read both sheets from the Excel file
import pandas as pd

df_sheet1 = pd.read_excel('b.xlsx')
df_master = df_new_Master

# Identify the relevant parameter columns based on the given range
start_col = 'Acetamiprid, mg/kg'
end_col = 'FSSR Limits Copper Oxychloride (Copper determined as elemental copper), mg/ kg'

# Get the list of columns that fall within the specified range
param_columns = list(df_sheet1.columns)
start_index = param_columns.index(start_col)
end_index = param_columns.index(end_col)
selected_params = param_columns[start_index:end_index+1]  # Ensure inclusive range

# Extract only parameter names (exclude 'FSSR Limits' ones)
params = [col for col in selected_params if not col.startswith('FSSR Limits')]

# Function to get the appropriate value from Master sheet
def get_master_value(commodity, parameter, variant):
    master_row = df_master[(df_master['Commodity'] == commodity) & 
                          (df_master['Parameter'] == parameter)]
    
    if not master_row.empty:
        if variant in ['Loose', 'Normal']:
            value = master_row['Max FSSAI Acceptable Value'].iloc[0]
        elif variant == 'Organic':
            value = master_row['Max FSSAI Acceptable Value - Organic'].iloc[0]
        else:
            return None
        
        if pd.isna(value):
            return None
        return str(value)
    return None

# Iterate through each row in Sheet1
for idx, row in df_sheet1.iterrows():
    commodity = row['Commodity']
    variant = row['Variant']
    
    for param in params:
        fssr_col = f'FSSR Limits {param}'
        compliance_col = f'{param} Compliance'
        
        # Ensure the compliance column exists
        if compliance_col not in df_sheet1.columns:
            df_sheet1[compliance_col] = None
        
        current_limit = df_sheet1.at[idx, fssr_col] if fssr_col in df_sheet1.columns else None
        current_value = df_sheet1.at[idx, param] if param in df_sheet1.columns else None
        
        # Always use 'Max' as limit type
        master_value = get_master_value(commodity, param, variant)
        
        if master_value is not None:
            # Update the FSSR Limits column with Max value
            df_sheet1.at[idx, fssr_col] = f"{current_limit} {master_value}"
            
            # Extract the numeric part of FSSR Limits
            try:
                limit_value = float(str(master_value).split()[0])  # Ensure numeric conversion
            except ValueError:
                limit_value = None
            
            if limit_value is not None and pd.notna(current_value):
                # Get decimal places from limit value
                decimal_places = len(str(limit_value).split('.')[-1]) if '.' in str(limit_value) else 0
                
                # Round the current value to the same decimal places
                rounded_value = round(float(current_value), decimal_places)
                
                # Check compliance
                df_sheet1.at[idx, compliance_col] = 'Safe' if rounded_value <= limit_value else 'Unsafe'

# Save the updated DataFrame
df_sheet1.to_excel('c.xlsx', index=False)
print("Successfully updated all FSSR Limits columns and added compliance checks")
# Out:
# Successfully updated all FSSR Limits columns and added compliance checks

# %%
# import pandas as pd
# import multiprocessing
# import numpy as np
# # Read both sheets from the Excel file
# df_sheet1 = pd.read_excel('param_updated_with_limits.xlsx')
# df_master = pd.read_excel('fssai-final.xlsx', sheet_name='Master')

# # Define the commodity mappings for Min values
# commodity_mappings = {
#     "Black Pepper Whole": [
#         "Diameter,mm", "Piperine Content (on dry basis),%", "Volatile oil on dry basis, %",
#         "Non-volatile ether extract on dry basis, %", "Bulk density, g/l"
#     ],
#     "Black Pepper Powder": [
#         "Piperine Content (on dry basis),%", "Volatile oil on dry basis, %", 
#         "Non-volatile ether extract on dry basis, %"
#     ],
#     "Cardamom powder": ["Volatile oil on dry basis, %"],
#     "Cardamon Whole": ["Volatile oil on dry basis, %"],
#     "Turmeric Powder": ["Colouring power expressed as curcuminoid content on dry basis, %"],
#     "Chilli Powder": ["Non-volatile ether extract on dry basis, %"],
#     "Coriander Whole": ["Volatile oil on dry basis, %"],
#     "Coriander Powder": ["Volatile oil on dry basis, %"],
#     "Cumin Powder": ["Volatile oil on dry basis, %"],
#     "Cumin Whole": ["Volatile oil content, ml/100g"]
# }

# # Function to get the appropriate value from the Master sheet
# def get_master_value(commodity, parameter, variant, limit_type='Min'):
#     master_row = df_master[(df_master['Commodity'] == commodity) & 
#                            (df_master['Parameter'] == parameter)]
    
#     if not master_row.empty:
#         if variant in ['Loose', 'Normal']:
#             value = master_row[f'Min FSSAI Acceptable Value' if limit_type == 'Min' else 'Max FSSAI Acceptable Value'].iloc[0]
#         elif variant == 'Organic':
#             value = master_row[f'Min FSSAI Acceptable Value - Organic' if limit_type == 'Min' else 'Max FSSAI Acceptable Value - Organic'].iloc[0]
#         else:
#             return None
        
#         return None if pd.isna(value) else str(value)
#     return None

# # Function to process a chunk of data
# def process_chunk(df_chunk):
#     for idx, row in df_chunk.iterrows():
#         commodity = row['Commodity']
#         variant = row['Variant']
        
#         param_columns = [col for col in df_chunk.columns if col not in ['Commodity', 'Variant'] 
#                          and not col.startswith('FSSR Limits')]
        
#         for param in param_columns:
#             fssr_col = f'FSSR Limits {param}'
#             current_limit = df_chunk.at[idx, fssr_col]
            
#             is_min = False
#             if commodity in commodity_mappings:
#                 is_min = param in commodity_mappings[commodity]
            
#             master_value = get_master_value(commodity, param, variant, 'Min' if is_min else 'Max')
            
#             if master_value is not None:
#                 df_chunk.at[idx, fssr_col] = f"{current_limit} {master_value}"
    
#     return df_chunk

# # Split the DataFrame into smaller chunks
# num_processes = multiprocessing.cpu_count()  # Use all available CPU cores
# df_chunks = np.array_split(df_sheet1, num_processes)

# # Use multiprocessing to process each chunk
# with multiprocessing.Pool(num_processes) as pool:
#     results = pool.map(process_chunk, df_chunks)

# # Combine all processed chunks into a single DataFrame
# df_updated = pd.concat(results)

# # Save the updated DataFrame
# df_updated.to_excel('param_updated_with_all_limits_and_values.xlsx', index=False)
# print("Successfully updated all FSSR Limits columns with values from Master sheet using multiprocessing.")

# %%
# Read the file with current FSSR limits and values
import pandas as pd
df_sheet1 = pd.read_excel('c.xlsx')
# df_master = pd.read_excel('Master.xlsx', sheet_name='Parameters Details')
df_master=df_new_Master

# Function to get unit from master sheet
def get_unit_from_master(commodity, parameter):
    # Find matching row in master sheet
    master_row = df_master[(df_master['Commodity'] == commodity) & 
                          (df_master['Parameter'] == parameter)]
    
    if not master_row.empty:
        unit = master_row['Units'].iloc[0]
        # Handle NaN or empty units
        if pd.isna(unit) or str(unit).strip() == '':
            return None
        return str(unit).strip()
    return None

# Iterate through each row in Sheet1
for idx, row in df_sheet1.iterrows():
    commodity = row['Commodity']
    
    # Get all FSSR Limits columns
    fssr_columns = [col for col in df_sheet1.columns if col.startswith('FSSR Limits')]
    
    for fssr_col in fssr_columns:
        # Extract the parameter name by removing 'FSSR Limits ' prefix
        param = fssr_col.replace('FSSR Limits ', '')
        
        # Get unit from master sheet
        unit = get_unit_from_master(commodity, param)
        
        if unit is not None:
            current_value = str(df_sheet1.at[idx, fssr_col])
            # Only add unit if it's not already present in the value    
            if unit not in current_value:
                df_sheet1.at[idx, fssr_col] = f"{current_value} {unit}"

# Save the updated DataFrame
df_sheet1.to_excel('d.xlsx', index=False)
print("Successfully added units to FSSR Limits columns")
# Out:
# Successfully added units to FSSR Limits columns

# %% [markdown]
# for removing Blanks

# %%
# # Define the start and end column names
# start_column = 'Acetamiprid, mg/kg'
# end_column = 'Copper Oxychloride (Copper determined as elemental copper), mg/ kg'

# # Get all column names
# columns = df_sheet1.columns.tolist()

# # Find the index of start and end columns
# start_col = columns.index(start_column)
# end_col = columns.index(end_column)

# # Create a list of columns between start and end columns (inclusive)
# param_columns = columns[start_col:end_col + 1]

# # Iterate through each row and update corresponding FSSR Limits column if value is blank
# for param in param_columns:
#     fssr_col = f'FSSR Limits {param}'
#     df_sheet1.loc[df_sheet1[param].isna(), fssr_col] = ""

# #saving
# df_sheet1.to_excel('param_updated_with_limits_values_and_units.xlsx', index=False)
# print("Successfully handeld Blanks units to FSSR Limits columns")

# %%
# Read the file with current FSSR limits and values
df = pd.read_excel('d.xlsx')

# Get the start and end columns for both series
start_param = 'Acetamiprid, mg/kg'
end_param = 'Copper Oxychloride (Copper determined as elemental copper), mg/ kg'
start_compliance = f"{start_param} Compliance"
end_compliance = f"{end_param} Compliance"

# Get all columns between start and end for both series
all_columns = df.columns.tolist()
start_idx = all_columns.index(start_param)
end_idx = all_columns.index(f"FSSR Limits {end_param}")

# Create lists of columns in each series
param_columns = []
fssr_columns = []
compliance_columns = []

current_param = None
for col in all_columns[start_idx:end_idx + 1]:
    if not col.startswith('FSSR Limits'):
        current_param = col
        param_columns.append(col)
        # Add corresponding compliance column
        compliance_columns.append(f"{col} Compliance")
    else:
        fssr_columns.append(col)

# Create new column order
new_columns = all_columns[:start_idx]  # Columns before our series
for i in range(len(param_columns)):
    new_columns.extend([
        param_columns[i],  
        compliance_columns[i],        # Original parameter column
        fssr_columns[i]         # FSSR Limits column
              # Compliance column
    ])
new_columns.extend(all_columns[end_idx + 1:])  # Columns after our series
# Ensure param_columns have numeric values
# df[param_columns] = df[param_columns].apply(pd.to_numeric, errors='coerce')

# Round values in param_columns to 1 decimal place
# df[param_columns] = df[param_columns].round(1)
# Reorder the DataFrame columns

# ******************* THIS IS THE PART OF SAFE AND UNSAFE**************************************

# import re

# # Function to extract numeric value from FSSR Limits column
# def extract_limit(value):
#     if isinstance(value, str):
#         match = re.search(r"[-+]?\d*\.\d+|\d+", value)  # Extract numeric part
#         if match:
#             return float(match.group())  # Convert to float
#     return None  # Return None if no valid number is found

# # Iterate over corresponding columns in param, fssr, and compliance
# for param_col, fssr_col, compliance_col in zip(param_columns, fssr_columns, compliance_columns):
#     # Extract numeric limit
#     df[fssr_col] = df[fssr_col].apply(extract_limit)

#     # Compare and set compliance column
#     df[compliance_col] = df.apply(lambda row: 'Unsafe' if row[param_col] > row[fssr_col] else 'Safe', axis=1)


# Save the updated DataFrame
# ndf.to_excel('param_updated_with_compliance_columns2.xlsx', index=False)



# ndf = df.reindex(columns=new_columns).iloc[:,0:718]
# df.reindex(columns)
# Save the updated DataFrame
df.to_excel('e.xlsx', index=False)
print("Successfully reordered columns with Compliance columns inserted")
# Out:
# Successfully reordered columns with Compliance columns inserted

# %%
# Separate columns into Banned and Not Banned
banned_param_cols = [col for col in param_columns if col in Banned_names]
banned_fssr_cols = [f"FSSR Limits {col}" for col in banned_param_cols]
banned_compliance_cols = [f"{col} Compliance" for col in banned_param_cols]

not_banned_param_cols = [col for col in param_columns if col in Not_Banned_names]
not_banned_fssr_cols = [f"FSSR Limits {col}" for col in not_banned_param_cols]
not_banned_compliance_cols = [f"{col} Compliance" for col in not_banned_param_cols]

# Create new column order with Banned first, then Not Banned
new_columns = all_columns[:start_idx]  # Columns before our series

# Insert Banned Pesticide Residue columns first
for i in range(len(banned_param_cols)):
    new_columns.extend([
        banned_param_cols[i],  
        banned_compliance_cols[i],  
        banned_fssr_cols[i]
    ])

# Insert Not Banned Pesticide Residue columns next
for i in range(len(not_banned_param_cols)):
    new_columns.extend([
        not_banned_param_cols[i],  
        not_banned_compliance_cols[i],  
        not_banned_fssr_cols[i]
    ])

# Add columns after our series
new_columns.extend(all_columns[end_idx + 1:])  


# Reorder DataFrame
ndf = df.reindex(columns=new_columns).iloc[:, 0:718]
# Round values in param_columns to match FSSR column precision

# Save the updated DataFrame
ndf.to_excel('f.xlsx', index=False)
print("Successfully reordered columns with Banned Pesticide Residue columns first.")
# Out:
# Successfully reordered columns with Banned Pesticide Residue columns first.

# %%
# Define the output file
ndf = ndf.iloc[1:].reset_index(drop=True)
output_file = 'final.xlsx'

# Create an Excel writer object
with pd.ExcelWriter(output_file, engine='openpyxl') as writer:
    # Save the original dataframe as a separate sheet
    ndf.to_excel(writer, sheet_name='Original_Data', index=False)
    
    # Loop through each unique commodity and create a separate sheet
    for commodity in ndf['Commodity'].unique():
        commodity_df = ndf[ndf['Commodity'] == commodity]
        commodity_df.to_excel(writer, sheet_name=commodity[:31], index=False)  # Excel limits sheet names to 31 chars

print("Successfully saved separate sheets for each Commodity along with the original data.")
# Out:
# Successfully saved separate sheets for each Commodity along with the original data.

# %%
# # Define the output file
# output_file = 'param_updated_with_compliance_Akash.xlsx'

# # Create an Excel writer object
# with pd.ExcelWriter(output_file, engine='openpyxl') as writer:
#     # Save the original dataframe as a separate sheet
#     ndf.to_excel(writer, sheet_name='Original_Data', index=False)
    
#     # Loop through each unique commodity and create a separate sheet
#     for commodity in ndf['Commodity'].unique():
#         columnsTokeep = df_new_Master.loc[
#             (df_new_Master['Key_Parameter'] == 'No') & 
#             (df_new_Master['Commodity'] == commodity), 
#             'Parameter'
#         ].drop_duplicates().tolist()
        
#         # Define which columns to keep
#         filtered_columns = ['Commodity', 'Variant']  # Always keep these
#         for param in columnsTokeep:
#             if param in param_columns:
#                 filtered_columns.extend([
#                     param, 
#                     f'FSSR Limits {param}', 
#                     f'{param} Compliance'
#                 ])
        
#         # Filter the dataframe
#         commodity_df = ndf[ndf['Commodity'] == commodity][filtered_columns]
        
#         # Save to Excel with a limited sheet name length
#         commodity_df.to_excel(writer, sheet_name=commodity[:31], index=False)

# print("Successfully saved separate sheets for each Commodity with filtered columns along with the original data.")

# %%
# # Define the output file
# output_file = 'param_updated_with_compliance_Akash_final.xlsx'

# # Create an Excel writer object
# with pd.ExcelWriter(output_file, engine='openpyxl') as writer:
#     # Save the original dataframe as a separate sheet
#     ndf.to_excel(writer, sheet_name='Original_Data', index=False)
    
#     # Always keep the first 19 columns
#     first_19_columns = ndf.columns[:19].tolist()

#     # Loop through each unique commodity and create a separate sheet
#     for commodity in ndf['Commodity'].unique():
#         columnsTokeep = df_new_Master.loc[
#             (df_new_Master['Key_Parameter'] == 'No') & 
#             (df_new_Master['Commodity'] == commodity), 
#             'Parameter'
#         ].drop_duplicates().tolist()
        
#         # Define which columns to keep
#         filtered_columns = first_19_columns  # Always keep the first 19 columns
#         for param in columnsTokeep:
#             if param in param_columns:
#                 filtered_columns.extend([
#                     param, 
#                     f'FSSR Limits {param}', 
#                     f'{param} Compliance'
#                 ])
        
#         # Filter the dataframe
#         commodity_df = ndf[ndf['Commodity'] == commodity][filtered_columns]
        
#         # Save to Excel with a limited sheet name length
#         commodity_df.to_excel(writer, sheet_name=commodity[:31], index=False)

# print("Successfully saved separate sheets for each Commodity with filtered columns along with the original data.")

# %%
# Define the output file
output_file = 'final_final.xlsx'

# Create an Excel writer object
with pd.ExcelWriter(output_file, engine='openpyxl') as writer:
    # Save the original dataframe as a separate sheet
    ndf.to_excel(writer, sheet_name='Original_Data', index=False)
    
    # Always keep the first 19 columns
    first_19_columns = df_new.columns[:19].tolist()

    # Loop through each unique commodity and create a separate sheet
    for commodity in ndf['Commodity'].unique():
        # Get the parameters to keep for the current commodity
        columnsTokeep = df_new_Master.loc[
            (df_new_Master['Key_Parameter'] == 'No') & 
            (df_new_Master['Commodity'] == commodity), 
            'Parameter'
        ].drop_duplicates().tolist()
        
        # Define the final list of columns to keep
        filtered_columns = first_19_columns.copy()  # Start with the first 19 columns
        for param in columnsTokeep:
            if param in param_columns:
                filtered_columns.extend([
                    param, 
                    f'FSSR Limits {param}', 
                    f'{param} Compliance'
                ])

        # Keep only the selected columns
        filtered_columns = list(dict.fromkeys(filtered_columns))  # Remove duplicates
        filtered_columns = [col for col in filtered_columns if col in ndf.columns]  # Ensure valid columns

        # Filter the dataframe for the current commodity
        commodity_df = ndf[ndf['Commodity'] == commodity][filtered_columns]

        # Save to Excel with a limited sheet name length
        commodity_df.to_excel(writer, sheet_name=commodity[:31], index=False)

print("Successfully saved separate sheets for each Commodity with filtered columns along with the original data.")
# Out:
# Successfully saved separate sheets for each Commodity with filtered columns along with the original data.

# %%
Banned_names
# Out:
# ['Methomyl, mg/kg',
#  'Carbofuran (sum of carbofuran and 3-hydroxy carbofuran expressed as carbofuran)',
#  'Methyl Parathion (combined residues of methyl parathion and its oxygen analogue to be determined and expressed as methyl parathion)',
#  'Aldicarb',
#  'Aldrin',
#  'Dieldrin',
#  'Chlordane',
#  'Heptalchlor',
#  'Lindane Gamma-HCH) Gamma (γ) Isomer (Known as Lindane)',
#  'Endosulfan',
#  'Phosphamidon',
#  'Captafol',
#  'Ferbam',
#  'Formothion',
#  'Simazine',
#  'Diazinon',
#  'D.D.T',
#  'Fenitrothion',
#  'Fenthion',
#  'Ethyl Parathion']

# %%
Not_Banned_names
# Out:
# ['Acetamiprid, mg/kg',
#  'Alpha naphthyl Acetic Acid, mg/kg',
#  'Azoxystrobin, mg/kg',
#  'Buprofezin, mg/kg',
#  'Carbaryl, mg/kg',
#  'Carbosulfan, mg/kg',
#  'Chlorantraniliprole, mg/kg',
#  'Chlorfenapyr, mg/kg',
#  'Cuprous Oxide (Copper determined as elemental copper) mg/kg',
#  'Cyantranilipole, mg/kg',
#  'Deltamethrin/Decamethrin, mg/kg',
#  'Diafenthiuron, mg/kg',
#  'Dicofol (Sum of p,p and o,p isomers), mg/kg',
#  'Difenoconazole, mg/kg',
#  'Dimethoate, mg/kg',
#  'Fenazaquin, mg/kg',
#  'Fenpropathrin, mg/kg',
#  'Fenpyroximate, mg/kg',
#  'Fipronil, mg/kg',
#  'Flubendiamide, mg/kg',
#  'Flusilazole, mg/kg',
#  'Hexaconazole, mg/kg',
#  'Hexythiazox, mg/kg',
#  'Imidacloprid, mg/kg',
#  'Indoxacarb, mg/kg',
#  'Kresoxim methyl, mg/kg',
#  'Lambda cyhalothrin, mg/kg',
#  'Lufenuron, mg/kg',
#  'Milbemectin, mg/kg',
#  'Monocrotophos, mg/kg',
#  'Myclobutanil, mg/kg',
#  'Novaluron, mg/kg',
#  'Oxydemeton methyl, mg/kg',
#  'Pendimethalin, mg/kg',
#  'Picoxystrobin, mg/kg',
#  'Propargite, mg/kg',
#  'Propineb, mg/kg',
#  'Pyraclostrobin, mg/kg',
#  'Pyridalyl, mg/kg',
#  'Pyriproxyfen, mg/kg',
#  'Quinalphos, mg/kg',
#  'Spinosad, mg/kg',
#  'Spiromesifen, mg/kg',
#  'Tebuconazole, mg/kg',
#  'Thiacloprid, mg/kg',
#  'Thiodicarb, mg/kg',
#  'Thiamethoxam, mg/kg',
#  'Triadimefon, mg/kg',
#  'Trifloxystrobin, mg/kg',
#  'Triazophos, mg/kg',
#  'Tricyclazole, mg/kg',
#  'Spinetoram and its metabolites\n(Spinosyn-J and Spinosyn-L), mg/kg',
#  'Spirotetramat, mg/kg',
#  'Abamectin, mg/kg',
#  'Dithiocarbamates (the residue tolerance limit are determined and expressed as mg/CS2/kg and refer separately to the residues arising from any or each group of dithiocarbamates)',
#  'Metiram as CS2, mg/kg',
#  '(b) Ethylene bis- dithiocarbamates resulting from the use of mancozeb, maneb or zineb (including zineb derived from nabam plus zinc\nsulphate)',
#  '(e) Zineb as CS2',
#  '2,4-Dichlorophenoxy Acetic Acid',
#  'Acephate (expressed as mixture of Methamidophos and acephate).',
#  'Alachlor',
#  'Alpha cypermethrin',
#  'Ametroctradin',
#  'Anilophos',
#  'Atrazine',
#  'Azimsulfuron',
#  'Benfuracarb',
#  'Sum of benomyl and carbendazim expressed as carbendazim',
#  'Bensulfuron Methyl',
#  'Beta Cyfluthrin',
#  'Bifenthrin',
#  'Bispyribac Sodium',
#  'Bitertanol',
#  'Butachlor',
#  'Captan',
#  'Carbendazim',
#  'Carfentrazone Ethyl',
#  'Carpropamid',
#  'Cartap Hydrochloride',
#  'Chlorfluazuron',
#  'Chlorimuron ethyl',
#  'Chlormequat Chloride (CCC)',
#  'Chlorothalonil',
#  'Chlorpropham',
#  'Chlorpyriphos',
#  'Chlothianidin (Chlothianidin and its metabolites Thiazolymethylguanidine (TMG), Thiazolymethylurea (TZMU), Methylnitroguanidine (MNG) TMG)',
#  'Chromafenozide',
#  'Cinmethylene',
#  'Clodinafop-propargyl',
#  'Clomazone',
#  'Copper Hydroxide (Copper determined as elemental copper)',
#  'Copper Sulphate (Copper determined as elemental copper',
#  'Cyazofamid',
#  'Cyhalofop-butyl',
#  'Cymoxanil',
#  'Cypermethrin (sum of isomers) (Fat soluble residue)',
#  'Dichlorvos (DDVP) (content of di- chloroacetaldehyde (D.C.A.) be reported where possible)',
#  'Diclofop (sum diclofop-methyl and diclofop\nacid expressed as diclofop-methyl)”',
#  'Diclosulam',
#  'Diflubenzuron',
#  'Dimethomorph',
#  'Dinocap',
#  'Dinotefuran',
#  'Dithianon',
#  'Diuron',
#  'Dodine',
#  'Edifenphos',
#  'Emamectin Benzoate',
#  'Epoxyconazole, mg/kg',
#  'Ethephon',
#  'Ethion(Residues to be determined as ethion and its oxygen analogue and expressed as ethion)',
#  'Ethofenprox (Etofenprox)',
#  'Ethoxysulfuron',
#  'Etoxazole',
#  'Famoxadone',
#  'Fenamidone',
#  'Fenarimol',
#  'Fenobucarb (BPMC)',
#  'Fenoxaprop-p-ethyl',
#  'Fenvalerate (Fat soluble residue)',
#  'Flonicamid',
#  'Fluazifop-p-butyl',
#  'Fluchloralin',
#  'Flufenacet',
#  'Fluvalinate',
#  'Forchlorfenuron',
#  'Fosetyl-Al, mg/kg',
#  'Glufosinate Ammonium',
#  'Glyphosate',
#  'Halosulfuron methyl',
#  'Hexazinone',
#  'Hydrogen Cyanamide',
#  'Iodosulfuron Methyl Sodium',
#  'Imazethapyr',
#  'Iprobenfos (Kitazin)',
#  'Iprodione',
#  'Isoprothiolane',
#  'Isoproturon',
#  'Kasugamycin',
#  'Linuron',
#  'Malathion (Malathion to be determined and expressed as combined residues of malathion and malaoxon)',
#  'Mandipropamid',
#  'Mepiquat Chloride',
#  'Mesosulfuron Methyl',
#  'Metaflumizone',
#  'Metalaxyl',
#  'Methabenzthiazuron',
#  'Methyl Chlorophenoxy Acetic Acid (MCPA)',
#  'Metolachlor',
#  'Metribuzin',
#  'Metsulfuron Methyl',
#  'Orthosulfamuron',
#  'Oxadiargyl, mg/kg',
#  'Oxadiazon',
#  'Oxyfluorfen',
#  'Paclobutrazol',
#  'Paraquat dichloride (Determined as Paraquatcations)',
#  'Penconazole',
#  'Pencycuron',
#  'Penoxuslum',
#  'Permethrin',
#  'Phenthoate',
#  'Phorate (sum of Phorate, its oxygen analogue and their sulphoxides and sulphones, expressed as phorate)',
#  'Phosalone',
#  'Pinoxaden',
#  'Pretilachlor',
#  'Pirimiphos-methyl',
#  'Profenofos',
#  'Prohexadione calcium',
#  'Propaquizafop',
#  'Propiconazole',
#  'Pyrazosulfuron ethyl',
#  'Pyrithiolac Sodium',
#  'Pymetrozine',
#  'Quizalofop ethyl',
#  'Quizalofop-P-tefuryl',
#  'Sodium Aceflourofen',
#  'Sulfosulfuron',
#  'Thifluzamide',
#  'Thiometon(Residues determined as thiometon its sulfoxide and sulphone expressed as thiometon)',
#  'Thiophanate-Methyl',
#  'Tolfenpyrad',
#  'Trichlorfon',
#  'Triacontanol',
#  'Triallate',
#  'Triasulfuron',
#  'Tridemorph',
#  'Trifluralin',
#  'Validamycin',
#  'Fluopicolide',
#  'Tembotrione',
#  'Propanil',
#  'Fluopyram and its metabolites',
#  'Topramezone',
#  'Thiocyclam Hydrogen Oxalate',
#  '2,4-D Amine Salt',
#  'Ametyrn',
#  'Fomesafen',
#  'Imazamox',
#  'Sodium Para Nitro Phenolate',
#  'Bentazone',
#  'Cyflumetofen',
#  'Boscalid',
#  'Flucetosulfuron',
#  'Haloxyfop-R Methyl',
#  'Sulfentrazone and its metabolite Desmethylsulfentrazone and 3- Hydroxymethylsulfentrazone',
#  'Metrafenone',
#  'Fluxapyroxad',
#  'Tetraconazole',
#  'Flupyradifurone and its metabolites Difluroacetic Acid and Difluroethylamino- furanone',
#  'Sulfoxaflor',
#  'Metalaxyl-M, mg/kg',
#  'Methomyl, mg/kg',
#  'Mancozeb, mg/kg',
#  'Copper Oxychloride (Copper determined as elemental copper), mg/ kg']
